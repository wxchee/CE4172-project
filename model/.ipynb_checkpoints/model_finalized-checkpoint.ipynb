# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import math
import pandas as pd

from sklearn.metrics import confusion_matrix
import seaborn as sb

# %%
# define constant

FOLDER = 'datas/s40d30t1.6/'
GESTURES = ["topl", "twistl", "side", "downl", "twistr", "topr", "downr","unknown"]

DATA_POINT_PER_GESTURE = 30

TARGET_DATA_POINT = 15

SEED = 1337
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Process data

# %%
inputs = []
outputs = []

ONE_HOTS = np.eye(len(GESTURES))

for i in range(len(GESTURES)):
    g = GESTURES[i]
    print(f"Processing {i} for gesture '{g}'.")

    output = ONE_HOTS[i]

    df = pd.read_csv(FOLDER + g + '.csv')
    num_recordings = int(df.shape[0] / DATA_POINT_PER_GESTURE)

    for j in range(num_recordings):
        tensor = []
        
        for k in range(DATA_POINT_PER_GESTURE):
            kk = j * DATA_POINT_PER_GESTURE + k
            if k < TARGET_DATA_POINT:
                tensor += [df['aX'][kk], df['aY'][kk], df['aZ'][kk], df['gX'][kk], df['gY'][kk], df['gZ'][kk]]
        
        inputs.append(tensor)
        outputs.append(output)
# Out:
# Processing 0 for gesture 'topl'.
# Processing 1 for gesture 'twistl'.
# Processing 2 for gesture 'side'.
# Processing 3 for gesture 'downl'.
# Processing 4 for gesture 'twistr'.
# Processing 5 for gesture 'topr'.
# Processing 6 for gesture 'downr'.
# Processing 7 for gesture 'unknown'.

# %% [markdown]
# ## Create train/validate/test datas

# %%
rdm_index = np.arange(len(inputs))
np.random.shuffle(rdm_index)

inputs = np.array(inputs)[rdm_index]
outputs = np.array(outputs)[rdm_index]

TRAIN_SPLIT = int(0.5 * len(inputs))
TEST_SPLIT = int(TRAIN_SPLIT + 0.25 * len(inputs))
i_train, i_validate, i_test = np.split(inputs, [TRAIN_SPLIT, TEST_SPLIT])
o_train, o_validate, o_test = np.split(outputs, [TRAIN_SPLIT, TEST_SPLIT])

i_train = tf.convert_to_tensor(i_train, dtype=tf.float32)
o_train = tf.convert_to_tensor(o_train, dtype=tf.float32)
i_validate = tf.convert_to_tensor(i_validate, dtype=tf.float32)
o_validate = tf.convert_to_tensor(o_validate, dtype=tf.float32)

i_test = tf.convert_to_tensor(i_test, dtype=tf.float32)

# %% [markdown]
# ## Build and train model

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']="TRUE"

EPOCHS=150

# %%
model = tf.keras.Sequential([
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(len(GESTURES), activation='softmax')
    ])
    
model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy(), metrics=['accuracy'])

history = model.fit(i_train, o_train, epochs=EPOCHS, batch_size=1,validation_data=(i_validate, o_validate))
# Out:
# Epoch 1/150
# 160/160 [==============================] - 1s 3ms/step - loss: 2.0409 - accuracy: 0.2688 - val_loss: 1.8046 - val_accuracy: 0.6125
# Epoch 2/150
# 160/160 [==============================] - 0s 2ms/step - loss: 1.6325 - accuracy: 0.5188 - val_loss: 1.4659 - val_accuracy: 0.5875
# Epoch 3/150
# 160/160 [==============================] - 0s 2ms/step - loss: 1.2313 - accuracy: 0.6562 - val_loss: 1.1500 - val_accuracy: 0.7250
# Epoch 4/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.9700 - accuracy: 0.7125 - val_loss: 0.9623 - val_accuracy: 0.6500
# Epoch 5/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.7675 - accuracy: 0.8000 - val_loss: 0.8090 - val_accuracy: 0.7500
# Epoch 6/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.6414 - accuracy: 0.8188 - val_loss: 0.7105 - val_accuracy: 0.7875
# Epoch 7/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5719 - accuracy: 0.8188 - val_loss: 0.5966 - val_accuracy: 0.8000
# Epoch 8/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5207 - accuracy: 0.8375 - val_loss: 0.5191 - val_accuracy: 0.8125
# Epoch 9/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4607 - accuracy: 0.8313 - val_loss: 0.5248 - val_accuracy: 0.8000
# Epoch 10/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4348 - accuracy: 0.8438 - val_loss: 0.4334 - val_accuracy: 0.8500
# Epoch 11/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4214 - accuracy: 0.8438 - val_loss: 0.4302 - val_accuracy: 0.9000
# Epoch 12/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3676 - accuracy: 0.8625 - val_loss: 0.4332 - val_accuracy: 0.9250
# Epoch 13/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3616 - accuracy: 0.8938 - val_loss: 0.3786 - val_accuracy: 0.8250
# Epoch 14/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.8875 - val_loss: 0.3704 - val_accuracy: 0.9375
# Epoch 15/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.8687 - val_loss: 0.3259 - val_accuracy: 0.9000
# Epoch 16/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.2902 - accuracy: 0.8938 - val_loss: 0.4242 - val_accuracy: 0.8625
# Epoch 17/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.2837 - accuracy: 0.9062 - val_loss: 0.3512 - val_accuracy: 0.9000
# Epoch 18/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.2969 - accuracy: 0.8875 - val_loss: 0.2899 - val_accuracy: 0.9125
# Epoch 19/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.2740 - accuracy: 0.9000 - val_loss: 0.2708 - val_accuracy: 0.9125
# Epoch 20/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.2571 - accuracy: 0.9000 - val_loss: 0.3129 - val_accuracy: 0.9250
# Epoch 21/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.2408 - accuracy: 0.9000 - val_loss: 0.2440 - val_accuracy: 0.9375
# Epoch 22/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.2109 - accuracy: 0.9250 - val_loss: 0.2521 - val_accuracy: 0.9250
# Epoch 23/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.2229 - accuracy: 0.9125 - val_loss: 0.3366 - val_accuracy: 0.8750
# Epoch 24/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.1940 - accuracy: 0.9375 - val_loss: 0.2693 - val_accuracy: 0.9250
# Epoch 25/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.1782 - accuracy: 0.9625 - val_loss: 0.1955 - val_accuracy: 0.9250
# Epoch 26/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.1765 - accuracy: 0.9438 - val_loss: 0.2001 - val_accuracy: 0.9750
# Epoch 27/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.1446 - accuracy: 0.9625 - val_loss: 0.1761 - val_accuracy: 0.9750
# Epoch 28/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.1737 - accuracy: 0.9125 - val_loss: 0.1800 - val_accuracy: 0.9750
# Epoch 29/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.1421 - accuracy: 0.9625 - val_loss: 0.1766 - val_accuracy: 0.9375
# Epoch 30/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.1374 - accuracy: 0.9688 - val_loss: 0.3819 - val_accuracy: 0.8375
# Epoch 31/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.1683 - accuracy: 0.9375 - val_loss: 0.1655 - val_accuracy: 0.9750
# Epoch 32/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.1362 - accuracy: 0.9688 - val_loss: 0.1422 - val_accuracy: 0.9750
# Epoch 33/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.1148 - accuracy: 0.9625 - val_loss: 0.1645 - val_accuracy: 0.9500
# Epoch 34/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.1018 - accuracy: 0.9750 - val_loss: 0.1891 - val_accuracy: 0.9125
# Epoch 35/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.1150 - accuracy: 0.9688 - val_loss: 0.2143 - val_accuracy: 0.9125
# Epoch 36/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.1207 - accuracy: 0.9625 - val_loss: 0.1694 - val_accuracy: 0.9375
# Epoch 37/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0985 - accuracy: 0.9812 - val_loss: 0.1184 - val_accuracy: 0.9875
# Epoch 38/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.1232 - accuracy: 0.9688 - val_loss: 0.2010 - val_accuracy: 0.9000
# Epoch 39/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0985 - accuracy: 0.9750 - val_loss: 0.1293 - val_accuracy: 0.9750
# Epoch 40/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0870 - accuracy: 0.9688 - val_loss: 0.1203 - val_accuracy: 0.9750
# Epoch 41/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0880 - accuracy: 0.9812 - val_loss: 0.1643 - val_accuracy: 0.9250
# Epoch 42/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0874 - accuracy: 0.9750 - val_loss: 0.1093 - val_accuracy: 0.9750
# Epoch 43/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0830 - accuracy: 0.9750 - val_loss: 0.1170 - val_accuracy: 0.9625
# Epoch 44/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0731 - accuracy: 0.9812 - val_loss: 0.1039 - val_accuracy: 0.9875
# Epoch 45/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0997 - accuracy: 0.9625 - val_loss: 0.2164 - val_accuracy: 0.9250
# Epoch 46/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0658 - accuracy: 0.9812 - val_loss: 0.0805 - val_accuracy: 0.9875
# Epoch 47/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0590 - accuracy: 0.9812 - val_loss: 0.1470 - val_accuracy: 0.9750
# Epoch 48/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0544 - accuracy: 0.9875 - val_loss: 0.1164 - val_accuracy: 0.9500
# Epoch 49/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0516 - accuracy: 0.9875 - val_loss: 0.1353 - val_accuracy: 0.9625
# Epoch 50/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0544 - accuracy: 0.9875 - val_loss: 0.1206 - val_accuracy: 0.9875
# Epoch 51/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0694 - accuracy: 0.9812 - val_loss: 0.2238 - val_accuracy: 0.9375
# Epoch 52/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0535 - accuracy: 0.9875 - val_loss: 0.1173 - val_accuracy: 0.9750
# Epoch 53/150
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0452 - accuracy: 0.9937 - val_loss: 0.2024 - val_accuracy: 0.9000
# Epoch 54/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0967 - accuracy: 0.9688 - val_loss: 0.1139 - val_accuracy: 0.9500
# Epoch 55/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0554 - accuracy: 0.9812 - val_loss: 0.1205 - val_accuracy: 0.9750
# Epoch 56/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0589 - accuracy: 0.9750 - val_loss: 0.1113 - val_accuracy: 0.9750
# Epoch 57/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0301 - accuracy: 0.9937 - val_loss: 0.1821 - val_accuracy: 0.9375
# Epoch 58/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0633 - accuracy: 0.9812 - val_loss: 0.0820 - val_accuracy: 0.9625
# Epoch 59/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 0.9875 - val_loss: 0.0721 - val_accuracy: 0.9875
# Epoch 60/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0297 - accuracy: 0.9937 - val_loss: 0.0872 - val_accuracy: 0.9875
# Epoch 61/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0374 - accuracy: 0.9937 - val_loss: 0.1233 - val_accuracy: 0.9625
# Epoch 62/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0458 - accuracy: 0.9812 - val_loss: 0.1000 - val_accuracy: 0.9875
# Epoch 63/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0269 - accuracy: 0.9937 - val_loss: 0.1387 - val_accuracy: 0.9500
# Epoch 64/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 0.9937 - val_loss: 0.1299 - val_accuracy: 0.9750
# Epoch 65/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0331 - accuracy: 1.0000 - val_loss: 0.1883 - val_accuracy: 0.9750
# Epoch 66/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0500 - accuracy: 0.9812 - val_loss: 0.1403 - val_accuracy: 0.9500
# Epoch 67/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0479 - accuracy: 0.9812 - val_loss: 0.1558 - val_accuracy: 0.9625
# Epoch 68/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0354 - accuracy: 0.9937 - val_loss: 0.1165 - val_accuracy: 0.9750
# Epoch 69/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0406 - accuracy: 0.9812 - val_loss: 0.0977 - val_accuracy: 0.9750
# Epoch 70/150
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.0789 - val_accuracy: 0.9875
# Epoch 71/150
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9625
# Epoch 72/150
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.0582 - val_accuracy: 0.9875
# Epoch 73/150
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0654 - accuracy: 0.9688 - val_loss: 0.0913 - val_accuracy: 0.9750
# Epoch 74/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.0847 - val_accuracy: 0.9875
# Epoch 75/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.0802 - val_accuracy: 0.9750
# Epoch 76/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.0952 - val_accuracy: 0.9750
# Epoch 77/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.0866 - val_accuracy: 0.9875
# Epoch 78/150
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 0.9875
# Epoch 79/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0222 - accuracy: 0.9875 - val_loss: 0.1133 - val_accuracy: 0.9750
# Epoch 80/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0405 - accuracy: 0.9875 - val_loss: 0.0934 - val_accuracy: 0.9750
# Epoch 81/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 0.9937 - val_loss: 0.0910 - val_accuracy: 0.9875
# Epoch 82/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0972 - val_accuracy: 0.9750
# Epoch 83/150
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0873 - val_accuracy: 0.9875
# Epoch 84/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.0750 - val_accuracy: 0.9750
# Epoch 85/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0857 - val_accuracy: 0.9875
# Epoch 86/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.0765 - val_accuracy: 0.9875
# Epoch 87/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9875
# Epoch 88/150
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0314 - accuracy: 0.9937 - val_loss: 0.2034 - val_accuracy: 0.9625
# Epoch 89/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0872 - accuracy: 0.9750 - val_loss: 0.1060 - val_accuracy: 0.9875
# Epoch 90/150
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.0997 - val_accuracy: 0.9875
# Epoch 91/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9750
# Epoch 92/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.1133 - val_accuracy: 0.9750
# Epoch 93/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0721 - val_accuracy: 0.9875
# Epoch 94/150
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0672 - val_accuracy: 0.9875
# Epoch 95/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0752 - val_accuracy: 0.9875
# Epoch 96/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0833 - val_accuracy: 0.9875
# Epoch 97/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 0.9875
# Epoch 98/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0705 - val_accuracy: 0.9875
# Epoch 99/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0975 - val_accuracy: 0.9750
# Epoch 100/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 0.9750
# Epoch 101/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0899 - accuracy: 0.9563 - val_loss: 0.2229 - val_accuracy: 0.9000
# Epoch 102/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0722 - val_accuracy: 0.9750
# Epoch 103/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0703 - val_accuracy: 0.9875
# Epoch 104/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0687 - val_accuracy: 0.9875
# Epoch 105/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 0.9750
# Epoch 106/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0568 - val_accuracy: 0.9875
# Epoch 107/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 0.9875
# Epoch 108/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0685 - val_accuracy: 0.9750
# Epoch 109/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0544 - val_accuracy: 0.9875
# Epoch 110/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0622 - val_accuracy: 0.9875
# Epoch 111/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0679 - val_accuracy: 0.9750
# Epoch 112/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0772 - val_accuracy: 0.9750
# Epoch 113/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0695 - val_accuracy: 0.9750
# Epoch 114/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9875
# Epoch 115/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0595 - val_accuracy: 0.9750
# Epoch 116/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0641 - val_accuracy: 0.9875
# Epoch 117/150
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0641 - val_accuracy: 0.9875
# Epoch 118/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 0.9875
# Epoch 119/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0942 - val_accuracy: 0.9875
# Epoch 120/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1628 - accuracy: 0.9625 - val_loss: 0.0856 - val_accuracy: 0.9750
# Epoch 121/150
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.1043 - val_accuracy: 0.9750
# Epoch 122/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 0.9875
# Epoch 123/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0892 - val_accuracy: 0.9875
# Epoch 124/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0858 - val_accuracy: 0.9875
# Epoch 125/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 0.9875
# Epoch 126/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 0.9875
# Epoch 127/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0864 - val_accuracy: 0.9875
# Epoch 128/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 0.9875
# Epoch 129/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0879 - val_accuracy: 0.9875
# Epoch 130/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0892 - val_accuracy: 0.9875
# Epoch 131/150
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0828 - val_accuracy: 0.9875
# Epoch 132/150
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0828 - val_accuracy: 0.9875
# Epoch 133/150
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0846 - val_accuracy: 0.9875
# Epoch 134/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0842 - val_accuracy: 0.9875
# Epoch 135/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0840 - val_accuracy: 0.9875
# Epoch 136/150
# 160/160 [==============================] - 0s 2ms/step - loss: 9.9057e-04 - accuracy: 1.0000 - val_loss: 0.0681 - val_accuracy: 0.9875
# Epoch 137/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9875
# Epoch 138/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0823 - val_accuracy: 0.9875
# Epoch 139/150
# 160/160 [==============================] - 0s 3ms/step - loss: 9.9882e-04 - accuracy: 1.0000 - val_loss: 0.0824 - val_accuracy: 0.9875
# Epoch 140/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0643 - val_accuracy: 0.9875
# Epoch 141/150
# 160/160 [==============================] - 0s 2ms/step - loss: 9.1049e-04 - accuracy: 1.0000 - val_loss: 0.0696 - val_accuracy: 0.9875
# Epoch 142/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0802 - val_accuracy: 0.9875
# Epoch 143/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0799 - val_accuracy: 0.9875
# Epoch 144/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0807 - val_accuracy: 0.9875
# Epoch 145/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3991 - accuracy: 0.9062 - val_loss: 0.1646 - val_accuracy: 0.9625
# Epoch 146/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0232 - accuracy: 0.9937 - val_loss: 0.1190 - val_accuracy: 0.9750
# Epoch 147/150
# 160/160 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0960 - val_accuracy: 0.9750
# Epoch 148/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0981 - val_accuracy: 0.9875
# Epoch 149/150
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1006 - val_accuracy: 0.9875
# Epoch 150/150
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1029 - val_accuracy: 0.9875

# %% [markdown]
# ## Review models' performance

# %%
# increase the size of the graphs. The default size is (6,4).
# fig, axs = plt.subplots(1, 1, figsize=(9, 9))
# fig.tight_layout(pad=3.0)
# def plot_model_loss(history, title, i):
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'g.', label='Training loss')
plt.plot(epochs, val_loss, 'b.', label='Validation loss')
plt.title('Model 3 s15 train/validate loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
#     ax.show()

# for i, s in enumerate(histories):
#     plot_model_loss(histories[s], 'Model s'+ str(s) + ' train/validate loss', i)

# %%
# increase the size of the graphs. The default size is (6,4).
# fig, axs = plt.subplots(1, 1, figsize=(9, 9))
# fig.tight_layout(pad=3.0)
# def plot_model_accuracy(history, title, i):
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs = range(1, len(accuracy) + 1)

# ax = axs[0, 0]
plt.plot(epochs, accuracy, 'g.', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b.', label='Validation accuracy')
plt.title('Model 3 s15 accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# for i, s in enumerate(histories):
#     plot_model_accuracy(histories[s], 'Model s'+ str(s) + ' accuracy', i)

# %% [markdown]
# ## Verify models with test data

# %%
plt.figure(figsize=(5, 5))
predict = model.predict(i_test)
conf_mat = confusion_matrix(np.argmax(o_test, axis=1), np.argmax(predict, axis=1))
# ax = axs[0,0]
sb.heatmap(conf_mat, annot=True, cmap='Blues', fmt='g', cbar=False)
plt.title('Model 3 s15 predict test data')
plt.xlabel('Actual labels')
plt.ylabel('Predicted labels')
# Out:
# 3/3 [==============================] - 0s 3ms/step
# Text(33.22222222222222, 0.5, 'Predicted labels')

# %% [markdown]
# ## Produce model file (.tflite)
#
# Output both non-quantized and quantized model files

# %%
def representative_dataset_generator():
     # each scalar value inside a 2D array that is wrapped in a list
     for value in inputs:
         yield [np.array(value, dtype=np.float32, ndmin=2)]

TFLITE_FILE = 'tflite/final/gesture_model_3_s15.tflite'
TFLITE_FILE_Q = 'tflite/final/gesture_model_3_s15q.tflite'

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open(TFLITE_FILE, "wb").write(tflite_model)

converter_q = tf.lite.TFLiteConverter.from_keras_model(model)
converter_q.optimizations = [tf.lite.Optimize.DEFAULT]
converter_q.representative_dataset = representative_dataset_generator
tflite_model_q = converter_q.convert()
open(TFLITE_FILE_Q, "wb").write(tflite_model_q)

# Review size difference
basic_model_size = os.path.getsize(TFLITE_FILE)
print("Basic model 3 is {} bytes".format(basic_model_size))

basic_model_size_q = os.path.getsize(TFLITE_FILE_Q)
print("Quantized model 3 is {} bytes".format(basic_model_size_q))
# Out:
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmp3s9v8r1y\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpinxep773\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpinxep773\assets
# Basic model 3 is 30092 bytes
# Quantized model 3 is 10096 bytes
# C:\Users\cheew\anaconda3\envs\tf\lib\site-packages\tensorflow\lite\python\convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "

# %% [markdown]
# ## Verify the interpreter (.tflite)

# %%
TFLITE_FILE = 'tflite/final/gesture_model_3_s15.tflite'
model_tf = tf.lite.Interpreter(TFLITE_FILE)
model_tf.allocate_tensors()
model_tf_input_index = model_tf.get_input_details()[0]['index']
model_tf_output_index = model_tf.get_output_details()[0]['index']
predict_tf = []
for j in i_test:
# write the value to the input tensor
    i_tensor = tf.convert_to_tensor([j], dtype=tf.float32)
    model_tf.set_tensor(model_tf_input_index, i_tensor)
    # run inference
    model_tf.invoke()
    # read the prediction from the output tensor
    predict_tf.append(model_tf.get_tensor(model_tf_output_index)[0])

conf_mat = confusion_matrix(np.argmax(o_test, axis=1), np.argmax(predict_tf, axis=1))

plt.figure(figsize=(5, 5))

sb.heatmap(conf_mat, annot=True, cmap='Blues', fmt='g', cbar=False)
plt.title("Model 3 s15")
plt.xlabel("Actual labels")
plt.ylabel("Predicted labels")
# Out:
# Text(33.22222222222222, 0.5, 'Predicted labels')

# %% [markdown]
# ## Verify the quantized interpreter (.tflite)

# %%
TFLITE_FILE_Q = 'tflite/final/gesture_model_3_s15q.tflite'
model_tf_q = tf.lite.Interpreter(TFLITE_FILE_Q)
model_tf_q.allocate_tensors()
model_tf_q_input_index = model_tf_q.get_input_details()[0]['index']
model_tf_q_output_index = model_tf_q.get_output_details()[0]['index']
predict_tf_q = []
for j in i_test:
# write the value to the input tensor
    i_tensor = tf.convert_to_tensor([j], dtype=tf.float32)
    model_tf_q.set_tensor(model_tf_q_input_index, i_tensor)
    # run inference
    model_tf_q.invoke()
    # read the prediction from the output tensor
    predict_tf_q.append(model_tf_q.get_tensor(model_tf_q_output_index)[0])

conf_mat = confusion_matrix(np.argmax(o_test, axis=1), np.argmax(predict_tf_q, axis=1))
plt.figure(figsize=(5, 5))

sb.heatmap(conf_mat, annot=True, cmap='Blues', fmt='g', cbar=False)
plt.title("Model 3 s15 quantized")
plt.xlabel("Actual labels")
plt.ylabel("Predicted labels")
# Out:
# Text(33.22222222222222, 0.5, 'Predicted labels')

# %% [markdown]
# ## Produce the model header file

# %%
# to run below command, ensure jupyter notebook is launched under bash terminal (eg. git bash, linux terminal)
TFLITE_FILE = 'tflite/final/gesture_model_3_s15.tflite'
TFLITE_FILE_Q = 'tflite/final/gesture_model_3_s15q.tflite'

HEADER_FILE = '../ble_client/final/gesture_model_3_s15.h'
HEADER_FILE_Q = '../ble_client/final/gesture_model_3_s15q.h'
# based model header file
str1 = "const unsigned char {} [] = {{".format('gesture_model')
str2 = "};"

# !echo {str1}  > {HEADER_FILE}
# !cat {TFLITE_FILE} | xxd -i >> {HEADER_FILE}
# !echo {str2} >> {HEADER_FILE}

# quantized model header file
str3 = "const unsigned char {} [] = {{".format('gesture_model_q')

# !echo {str3}  > {HEADER_FILE_Q}
# !cat {TFLITE_FILE_Q} | xxd -i >> {HEADER_FILE_Q}
# !echo {str2} >> {HEADER_FILE_Q}
