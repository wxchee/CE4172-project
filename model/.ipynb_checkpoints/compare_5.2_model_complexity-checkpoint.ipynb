# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import math
import pandas as pd

from sklearn.metrics import confusion_matrix
import seaborn as sb

# %%
# define constant

FOLDER = 'datas/s40d30t1.6/'
GESTURES = ["topl", "twistl", "side", "downl", "twistr", "topr", "downr","unknown"]

DATA_POINT_PER_GESTURE = 30


SEED = 1337
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Process data

# %%
inputs = []
outputs = []

ONE_HOTS = np.eye(len(GESTURES))

for i in range(len(GESTURES)):
    g = GESTURES[i]
    print(f"Processing {i} for gesture '{g}'.")
    
    output = ONE_HOTS[i]
    
    df = pd.read_csv(FOLDER + g + '.csv')
    num_recordings = int(df.shape[0] / DATA_POINT_PER_GESTURE)
    
    for j in range(num_recordings):
        tensor = []
        
        for k in range(DATA_POINT_PER_GESTURE):
            kk = j * DATA_POINT_PER_GESTURE + k
            
            tensor += [
                df['aX'][kk],
                df['aY'][kk],
                df['aZ'][kk],
                df['gX'][kk],
                df['gY'][kk],
                df['gZ'][kk],
#                 df['mX'][kk],
#                 df['mY'][kk],
#                 df['mZ'][kk],
            ]
            
        inputs.append(tensor)
        outputs.append(output)
# Out:
# Processing 0 for gesture 'topl'.
# Processing 1 for gesture 'twistl'.
# Processing 2 for gesture 'side'.
# Processing 3 for gesture 'downl'.
# Processing 4 for gesture 'twistr'.
# Processing 5 for gesture 'topr'.
# Processing 6 for gesture 'downr'.
# Processing 7 for gesture 'unknown'.

# %%
# display(pd.DataFrame(inputs))

# %% [markdown]
# ## Create train/validate/test datas

# %%
rdm_index = np.arange(len(inputs))
np.random.shuffle(rdm_index)

inputs = np.array(inputs)[rdm_index]
outputs = np.array(outputs)[rdm_index]

TRAIN_SPLIT = int(0.5 * len(inputs))
TEST_SPLIT = int(TRAIN_SPLIT + 0.25 * len(inputs))

i_train, i_validate, i_test = np.split(inputs, [TRAIN_SPLIT, TEST_SPLIT])
o_train, o_validate, o_test = np.split(outputs, [TRAIN_SPLIT, TEST_SPLIT])

# do this if data type invalid
i_train = tf.convert_to_tensor(i_train, dtype=tf.float32)
o_train = tf.convert_to_tensor(o_train, dtype=tf.float32)

i_validate = tf.convert_to_tensor(i_validate, dtype=tf.float32)
o_validate = tf.convert_to_tensor(o_validate, dtype=tf.float32)

i_test = tf.convert_to_tensor(i_test, dtype=tf.float32)

# %% [markdown]
# ## Build and train model

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']="TRUE"

EPOCHS=150

# %%
def create_model(n1, n2, epoch=EPOCHS):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(n1, activation='relu'),
        tf.keras.layers.Dense(n2, activation='relu'),
        tf.keras.layers.Dense(len(GESTURES), activation='softmax')
    ])
    
    model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy(), metrics=['accuracy'])
    history = model.fit(i_train, o_train, epochs=epoch, batch_size=1,validation_data=(i_validate, o_validate))
    
    return model, history

# %%
model1, history1 = create_model(64, 32, 40)
# Out:
# Epoch 1/40
# 160/160 [==============================] - 1s 5ms/step - loss: 2.0311 - accuracy: 0.2500 - val_loss: 1.8543 - val_accuracy: 0.4625
# Epoch 2/40
# 160/160 [==============================] - 0s 3ms/step - loss: 1.7483 - accuracy: 0.4250 - val_loss: 1.5943 - val_accuracy: 0.5000
# Epoch 3/40
# 160/160 [==============================] - 1s 3ms/step - loss: 1.3885 - accuracy: 0.5875 - val_loss: 1.4138 - val_accuracy: 0.4875
# Epoch 4/40
# 160/160 [==============================] - 1s 3ms/step - loss: 1.1272 - accuracy: 0.6250 - val_loss: 1.1418 - val_accuracy: 0.6250
# Epoch 5/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.8273 - accuracy: 0.7563 - val_loss: 0.8359 - val_accuracy: 0.7250
# Epoch 6/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.6545 - accuracy: 0.8062 - val_loss: 0.6791 - val_accuracy: 0.8375
# Epoch 7/40
# 160/160 [==============================] - 1s 4ms/step - loss: 0.5450 - accuracy: 0.8188 - val_loss: 0.6447 - val_accuracy: 0.7250
# Epoch 8/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.5085 - accuracy: 0.8250 - val_loss: 0.5350 - val_accuracy: 0.7375
# Epoch 9/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4350 - accuracy: 0.9000 - val_loss: 0.4539 - val_accuracy: 0.8750
# Epoch 10/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3866 - accuracy: 0.8938 - val_loss: 0.4845 - val_accuracy: 0.8875
# Epoch 11/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3934 - accuracy: 0.8562 - val_loss: 0.3940 - val_accuracy: 0.8625
# Epoch 12/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3279 - accuracy: 0.9187 - val_loss: 0.4843 - val_accuracy: 0.8750
# Epoch 13/40
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3142 - accuracy: 0.9000 - val_loss: 0.3162 - val_accuracy: 0.9125
# Epoch 14/40
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2726 - accuracy: 0.9187 - val_loss: 0.2542 - val_accuracy: 0.9375
# Epoch 15/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2724 - accuracy: 0.9000 - val_loss: 0.2349 - val_accuracy: 0.9125
# Epoch 16/40
# 160/160 [==============================] - 1s 4ms/step - loss: 0.2613 - accuracy: 0.9187 - val_loss: 0.3191 - val_accuracy: 0.8625
# Epoch 17/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2285 - accuracy: 0.9312 - val_loss: 0.2881 - val_accuracy: 0.9125
# Epoch 18/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2295 - accuracy: 0.9375 - val_loss: 0.1770 - val_accuracy: 0.9625
# Epoch 19/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1799 - accuracy: 0.9438 - val_loss: 0.3292 - val_accuracy: 0.8500
# Epoch 20/40
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2508 - accuracy: 0.9062 - val_loss: 0.2701 - val_accuracy: 0.9125
# Epoch 21/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1972 - accuracy: 0.9438 - val_loss: 0.1893 - val_accuracy: 0.9250
# Epoch 22/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1782 - accuracy: 0.9375 - val_loss: 0.2515 - val_accuracy: 0.9250
# Epoch 23/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1869 - accuracy: 0.9187 - val_loss: 0.1670 - val_accuracy: 0.9375
# Epoch 24/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1350 - accuracy: 0.9688 - val_loss: 0.1279 - val_accuracy: 0.9625
# Epoch 25/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1183 - accuracy: 0.9688 - val_loss: 0.1514 - val_accuracy: 0.9125
# Epoch 26/40
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1744 - accuracy: 0.9375 - val_loss: 0.0974 - val_accuracy: 0.9750
# Epoch 27/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1024 - accuracy: 0.9812 - val_loss: 0.1539 - val_accuracy: 0.9500
# Epoch 28/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1846 - accuracy: 0.9312 - val_loss: 0.1107 - val_accuracy: 0.9750
# Epoch 29/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1010 - accuracy: 0.9750 - val_loss: 0.1200 - val_accuracy: 1.0000
# Epoch 30/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1047 - accuracy: 0.9625 - val_loss: 0.2187 - val_accuracy: 0.9375
# Epoch 31/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1207 - accuracy: 0.9625 - val_loss: 0.1003 - val_accuracy: 0.9750
# Epoch 32/40
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1018 - accuracy: 0.9688 - val_loss: 0.0711 - val_accuracy: 1.0000
# Epoch 33/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1012 - accuracy: 0.9625 - val_loss: 0.4196 - val_accuracy: 0.7625
# Epoch 34/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0852 - accuracy: 0.9688 - val_loss: 0.1618 - val_accuracy: 0.9250
# Epoch 35/40
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1150 - accuracy: 0.9625 - val_loss: 0.3697 - val_accuracy: 0.8875
# Epoch 36/40
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1081 - accuracy: 0.9625 - val_loss: 0.1188 - val_accuracy: 0.9625
# Epoch 37/40
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1034 - accuracy: 0.9625 - val_loss: 0.0645 - val_accuracy: 1.0000
# Epoch 38/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1258 - accuracy: 0.9563 - val_loss: 0.1731 - val_accuracy: 0.9250
# Epoch 39/40
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1398 - accuracy: 0.9625 - val_loss: 0.0676 - val_accuracy: 0.9750
# Epoch 40/40
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1182 - accuracy: 0.9563 - val_loss: 0.0792 - val_accuracy: 1.0000

# %%
model2, history2 = create_model(32, 16, 60)
# Out:
# Epoch 1/60
# 160/160 [==============================] - 1s 4ms/step - loss: 2.1176 - accuracy: 0.1875 - val_loss: 2.0187 - val_accuracy: 0.2375
# Epoch 2/60
# 160/160 [==============================] - 0s 3ms/step - loss: 1.8870 - accuracy: 0.3750 - val_loss: 1.8844 - val_accuracy: 0.2750
# Epoch 3/60
# 160/160 [==============================] - 0s 3ms/step - loss: 1.7032 - accuracy: 0.4500 - val_loss: 1.7275 - val_accuracy: 0.2750
# Epoch 4/60
# 160/160 [==============================] - 1s 3ms/step - loss: 1.5552 - accuracy: 0.4062 - val_loss: 1.5883 - val_accuracy: 0.4125
# Epoch 5/60
# 160/160 [==============================] - 0s 3ms/step - loss: 1.3837 - accuracy: 0.5500 - val_loss: 1.4901 - val_accuracy: 0.4250
# Epoch 6/60
# 160/160 [==============================] - 0s 3ms/step - loss: 1.1871 - accuracy: 0.6187 - val_loss: 1.3223 - val_accuracy: 0.4375
# Epoch 7/60
# 160/160 [==============================] - 0s 3ms/step - loss: 1.0348 - accuracy: 0.6500 - val_loss: 1.0759 - val_accuracy: 0.6750
# Epoch 8/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.9026 - accuracy: 0.6687 - val_loss: 0.9262 - val_accuracy: 0.7875
# Epoch 9/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.7637 - accuracy: 0.7375 - val_loss: 0.8277 - val_accuracy: 0.8500
# Epoch 10/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.7004 - accuracy: 0.8375 - val_loss: 0.7458 - val_accuracy: 0.8750
# Epoch 11/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.6291 - accuracy: 0.8188 - val_loss: 0.6970 - val_accuracy: 0.9000
# Epoch 12/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.5666 - accuracy: 0.8375 - val_loss: 0.6265 - val_accuracy: 0.8500
# Epoch 13/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.5098 - accuracy: 0.8500 - val_loss: 0.6345 - val_accuracy: 0.7625
# Epoch 14/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4839 - accuracy: 0.8562 - val_loss: 0.5097 - val_accuracy: 0.8750
# Epoch 15/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4561 - accuracy: 0.8375 - val_loss: 0.4983 - val_accuracy: 0.9000
# Epoch 16/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4031 - accuracy: 0.8750 - val_loss: 0.4735 - val_accuracy: 0.9125
# Epoch 17/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3823 - accuracy: 0.8875 - val_loss: 0.4161 - val_accuracy: 0.9625
# Epoch 18/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3922 - accuracy: 0.8562 - val_loss: 0.3579 - val_accuracy: 0.9125
# Epoch 19/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3283 - accuracy: 0.9062 - val_loss: 0.3770 - val_accuracy: 0.8875
# Epoch 20/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3709 - accuracy: 0.8875 - val_loss: 0.3397 - val_accuracy: 0.9250
# Epoch 21/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2939 - accuracy: 0.9187 - val_loss: 0.3019 - val_accuracy: 0.9250
# Epoch 22/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2770 - accuracy: 0.9250 - val_loss: 0.2920 - val_accuracy: 0.9375
# Epoch 23/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2845 - accuracy: 0.9062 - val_loss: 0.3477 - val_accuracy: 0.8875
# Epoch 24/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2353 - accuracy: 0.9500 - val_loss: 0.3406 - val_accuracy: 0.9000
# Epoch 25/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2462 - accuracy: 0.9500 - val_loss: 0.2051 - val_accuracy: 0.9750
# Epoch 26/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2354 - accuracy: 0.9500 - val_loss: 0.2078 - val_accuracy: 0.9625
# Epoch 27/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2057 - accuracy: 0.9438 - val_loss: 0.2981 - val_accuracy: 0.9000
# Epoch 28/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2285 - accuracy: 0.9250 - val_loss: 0.1660 - val_accuracy: 0.9750
# Epoch 29/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1925 - accuracy: 0.9438 - val_loss: 0.1613 - val_accuracy: 0.9875
# Epoch 30/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1829 - accuracy: 0.9563 - val_loss: 0.2792 - val_accuracy: 0.9125
# Epoch 31/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1926 - accuracy: 0.9312 - val_loss: 0.2116 - val_accuracy: 0.9375
# Epoch 32/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1707 - accuracy: 0.9563 - val_loss: 0.1412 - val_accuracy: 1.0000
# Epoch 33/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1685 - accuracy: 0.9500 - val_loss: 0.1386 - val_accuracy: 1.0000
# Epoch 34/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1437 - accuracy: 0.9750 - val_loss: 0.2341 - val_accuracy: 0.9000
# Epoch 35/60
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1586 - accuracy: 0.9563 - val_loss: 0.1698 - val_accuracy: 0.9375
# Epoch 36/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1545 - accuracy: 0.9500 - val_loss: 0.1288 - val_accuracy: 0.9750
# Epoch 37/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1406 - accuracy: 0.9563 - val_loss: 0.1098 - val_accuracy: 1.0000
# Epoch 38/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1571 - accuracy: 0.9375 - val_loss: 0.2127 - val_accuracy: 0.9000
# Epoch 39/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1432 - accuracy: 0.9563 - val_loss: 0.1008 - val_accuracy: 1.0000
# Epoch 40/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1585 - accuracy: 0.9438 - val_loss: 0.0832 - val_accuracy: 1.0000
# Epoch 41/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1336 - accuracy: 0.9500 - val_loss: 0.1050 - val_accuracy: 0.9750
# Epoch 42/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1157 - accuracy: 0.9688 - val_loss: 0.1069 - val_accuracy: 0.9875
# Epoch 43/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1085 - accuracy: 0.9563 - val_loss: 0.0897 - val_accuracy: 1.0000
# Epoch 44/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1214 - accuracy: 0.9563 - val_loss: 0.1338 - val_accuracy: 0.9625
# Epoch 45/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1186 - accuracy: 0.9625 - val_loss: 0.1637 - val_accuracy: 0.9500
# Epoch 46/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1014 - accuracy: 0.9750 - val_loss: 0.1143 - val_accuracy: 0.9500
# Epoch 47/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1174 - accuracy: 0.9563 - val_loss: 0.0722 - val_accuracy: 1.0000
# Epoch 48/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1040 - accuracy: 0.9625 - val_loss: 0.0933 - val_accuracy: 0.9750
# Epoch 49/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0850 - accuracy: 0.9875 - val_loss: 0.0852 - val_accuracy: 1.0000
# Epoch 50/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0865 - accuracy: 0.9812 - val_loss: 0.0834 - val_accuracy: 0.9875
# Epoch 51/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1140 - accuracy: 0.9688 - val_loss: 0.0786 - val_accuracy: 0.9875
# Epoch 52/60
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0899 - accuracy: 0.9812 - val_loss: 0.0724 - val_accuracy: 1.0000
# Epoch 53/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0972 - accuracy: 0.9750 - val_loss: 0.1276 - val_accuracy: 0.9375
# Epoch 54/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1061 - accuracy: 0.9688 - val_loss: 0.0590 - val_accuracy: 1.0000
# Epoch 55/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0767 - accuracy: 0.9875 - val_loss: 0.0682 - val_accuracy: 1.0000
# Epoch 56/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0977 - accuracy: 0.9750 - val_loss: 0.1335 - val_accuracy: 0.9375
# Epoch 57/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0790 - accuracy: 0.9750 - val_loss: 0.0746 - val_accuracy: 1.0000
# Epoch 58/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1018 - accuracy: 0.9688 - val_loss: 0.1216 - val_accuracy: 0.9375
# Epoch 59/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0695 - accuracy: 0.9750 - val_loss: 0.0560 - val_accuracy: 1.0000
# Epoch 60/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0751 - accuracy: 0.9750 - val_loss: 0.0454 - val_accuracy: 1.0000

# %%
model3, history3 = create_model(16, 8, 100)
# Out:
# Epoch 1/100
# 160/160 [==============================] - 1s 4ms/step - loss: 2.0625 - accuracy: 0.1813 - val_loss: 2.0622 - val_accuracy: 0.1125
# Epoch 2/100
# 160/160 [==============================] - 0s 3ms/step - loss: 2.0052 - accuracy: 0.2313 - val_loss: 2.0610 - val_accuracy: 0.2375
# Epoch 3/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.9400 - accuracy: 0.2875 - val_loss: 1.9932 - val_accuracy: 0.2250
# Epoch 4/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.8536 - accuracy: 0.3063 - val_loss: 1.8966 - val_accuracy: 0.3125
# Epoch 5/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.7241 - accuracy: 0.4187 - val_loss: 1.8285 - val_accuracy: 0.3125
# Epoch 6/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.5973 - accuracy: 0.4000 - val_loss: 1.7667 - val_accuracy: 0.3125
# Epoch 7/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.5144 - accuracy: 0.4062 - val_loss: 1.6553 - val_accuracy: 0.3000
# Epoch 8/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.4396 - accuracy: 0.4250 - val_loss: 1.5944 - val_accuracy: 0.3125
# Epoch 9/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.3775 - accuracy: 0.4938 - val_loss: 1.5236 - val_accuracy: 0.4750
# Epoch 10/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.3043 - accuracy: 0.5750 - val_loss: 1.4655 - val_accuracy: 0.5250
# Epoch 11/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.2155 - accuracy: 0.6125 - val_loss: 1.3367 - val_accuracy: 0.5125
# Epoch 12/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.1175 - accuracy: 0.6187 - val_loss: 1.2971 - val_accuracy: 0.5125
# Epoch 13/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.0479 - accuracy: 0.6062 - val_loss: 1.2812 - val_accuracy: 0.4250
# Epoch 14/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.9972 - accuracy: 0.6438 - val_loss: 1.0978 - val_accuracy: 0.6125
# Epoch 15/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.9423 - accuracy: 0.6625 - val_loss: 1.0575 - val_accuracy: 0.6125
# Epoch 16/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.8786 - accuracy: 0.7000 - val_loss: 1.0114 - val_accuracy: 0.6250
# Epoch 17/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.8353 - accuracy: 0.7500 - val_loss: 1.0638 - val_accuracy: 0.5000
# Epoch 18/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.8438 - accuracy: 0.7000 - val_loss: 0.9046 - val_accuracy: 0.7250
# Epoch 19/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.7745 - accuracy: 0.7812 - val_loss: 0.9114 - val_accuracy: 0.7125
# Epoch 20/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.7619 - accuracy: 0.7437 - val_loss: 0.8620 - val_accuracy: 0.8125
# Epoch 21/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.7268 - accuracy: 0.7625 - val_loss: 0.8019 - val_accuracy: 0.8125
# Epoch 22/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.7011 - accuracy: 0.7875 - val_loss: 0.7625 - val_accuracy: 0.8500
# Epoch 23/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.6694 - accuracy: 0.7750 - val_loss: 0.7185 - val_accuracy: 0.8250
# Epoch 24/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.6095 - accuracy: 0.8500 - val_loss: 0.8119 - val_accuracy: 0.7375
# Epoch 25/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.6176 - accuracy: 0.8062 - val_loss: 0.6231 - val_accuracy: 0.8625
# Epoch 26/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.5562 - accuracy: 0.8375 - val_loss: 0.5723 - val_accuracy: 0.8875
# Epoch 27/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.5144 - accuracy: 0.8625 - val_loss: 0.5899 - val_accuracy: 0.7875
# Epoch 28/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4964 - accuracy: 0.8438 - val_loss: 0.5565 - val_accuracy: 0.8125
# Epoch 29/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.5013 - accuracy: 0.8250 - val_loss: 0.4982 - val_accuracy: 0.9125
# Epoch 30/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4486 - accuracy: 0.8562 - val_loss: 0.5387 - val_accuracy: 0.8375
# Epoch 31/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4323 - accuracy: 0.8625 - val_loss: 0.5480 - val_accuracy: 0.7500
# Epoch 32/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4306 - accuracy: 0.8375 - val_loss: 0.4259 - val_accuracy: 0.9250
# Epoch 33/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3863 - accuracy: 0.8938 - val_loss: 0.4278 - val_accuracy: 0.9250
# Epoch 34/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3692 - accuracy: 0.8813 - val_loss: 0.4553 - val_accuracy: 0.8625
# Epoch 35/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3603 - accuracy: 0.8875 - val_loss: 0.3936 - val_accuracy: 0.9000
# Epoch 36/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.3777 - accuracy: 0.8562 - val_loss: 0.4142 - val_accuracy: 0.8000
# Epoch 37/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3462 - accuracy: 0.9125 - val_loss: 0.3807 - val_accuracy: 0.8625
# Epoch 38/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3515 - accuracy: 0.8687 - val_loss: 0.4626 - val_accuracy: 0.7875
# Epoch 39/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3220 - accuracy: 0.9062 - val_loss: 0.3404 - val_accuracy: 0.9625
# Epoch 40/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3204 - accuracy: 0.9125 - val_loss: 0.3500 - val_accuracy: 0.9250
# Epoch 41/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3252 - accuracy: 0.8875 - val_loss: 0.3541 - val_accuracy: 0.8625
# Epoch 42/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2901 - accuracy: 0.9000 - val_loss: 0.2992 - val_accuracy: 0.9375
# Epoch 43/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2796 - accuracy: 0.9062 - val_loss: 0.3361 - val_accuracy: 0.8875
# Epoch 44/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2856 - accuracy: 0.9312 - val_loss: 0.3359 - val_accuracy: 0.9000
# Epoch 45/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2752 - accuracy: 0.9250 - val_loss: 0.2830 - val_accuracy: 0.9500
# Epoch 46/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2677 - accuracy: 0.9187 - val_loss: 0.2876 - val_accuracy: 0.9125
# Epoch 47/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2700 - accuracy: 0.9250 - val_loss: 0.2448 - val_accuracy: 0.9500
# Epoch 48/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2549 - accuracy: 0.9062 - val_loss: 0.2466 - val_accuracy: 0.9250
# Epoch 49/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2368 - accuracy: 0.9438 - val_loss: 0.2460 - val_accuracy: 0.9625
# Epoch 50/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2263 - accuracy: 0.9500 - val_loss: 0.2503 - val_accuracy: 0.9625
# Epoch 51/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2274 - accuracy: 0.9438 - val_loss: 0.2358 - val_accuracy: 0.9125
# Epoch 52/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2353 - accuracy: 0.9438 - val_loss: 0.2249 - val_accuracy: 0.9375
# Epoch 53/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2146 - accuracy: 0.9438 - val_loss: 0.2503 - val_accuracy: 0.9375
# Epoch 54/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.2140 - accuracy: 0.9375 - val_loss: 0.2689 - val_accuracy: 0.9000
# Epoch 55/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2222 - accuracy: 0.9125 - val_loss: 0.2094 - val_accuracy: 0.9500
# Epoch 56/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2052 - accuracy: 0.9500 - val_loss: 0.3162 - val_accuracy: 0.8625
# Epoch 57/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2006 - accuracy: 0.9375 - val_loss: 0.2495 - val_accuracy: 0.9250
# Epoch 58/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2102 - accuracy: 0.9438 - val_loss: 0.2008 - val_accuracy: 0.9250
# Epoch 59/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1729 - accuracy: 0.9563 - val_loss: 0.1848 - val_accuracy: 0.9875
# Epoch 60/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1784 - accuracy: 0.9375 - val_loss: 0.1848 - val_accuracy: 0.9750
# Epoch 61/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1894 - accuracy: 0.9375 - val_loss: 0.1751 - val_accuracy: 0.9500
# Epoch 62/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1840 - accuracy: 0.9438 - val_loss: 0.1633 - val_accuracy: 0.9500
# Epoch 63/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1950 - accuracy: 0.9312 - val_loss: 0.2155 - val_accuracy: 0.9250
# Epoch 64/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1981 - accuracy: 0.9312 - val_loss: 0.2141 - val_accuracy: 0.9625
# Epoch 65/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1788 - accuracy: 0.9375 - val_loss: 0.2061 - val_accuracy: 0.9250
# Epoch 66/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1788 - accuracy: 0.9500 - val_loss: 0.1565 - val_accuracy: 0.9625
# Epoch 67/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1511 - accuracy: 0.9688 - val_loss: 0.2123 - val_accuracy: 0.9250
# Epoch 68/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1710 - accuracy: 0.9625 - val_loss: 0.2045 - val_accuracy: 0.9750
# Epoch 69/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1353 - accuracy: 0.9625 - val_loss: 0.1873 - val_accuracy: 0.9375
# Epoch 70/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1670 - accuracy: 0.9438 - val_loss: 0.1786 - val_accuracy: 0.9500
# Epoch 71/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1286 - accuracy: 0.9625 - val_loss: 0.1339 - val_accuracy: 0.9875
# Epoch 72/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1379 - accuracy: 0.9625 - val_loss: 0.1482 - val_accuracy: 0.9625
# Epoch 73/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1541 - accuracy: 0.9438 - val_loss: 0.1922 - val_accuracy: 0.9250
# Epoch 74/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1739 - accuracy: 0.9438 - val_loss: 0.1759 - val_accuracy: 0.9875
# Epoch 75/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1675 - accuracy: 0.9438 - val_loss: 0.1357 - val_accuracy: 0.9500
# Epoch 76/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1266 - accuracy: 0.9625 - val_loss: 0.1239 - val_accuracy: 0.9875
# Epoch 77/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1276 - accuracy: 0.9688 - val_loss: 0.1282 - val_accuracy: 0.9625
# Epoch 78/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1177 - accuracy: 0.9625 - val_loss: 0.1440 - val_accuracy: 0.9500
# Epoch 79/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1311 - accuracy: 0.9625 - val_loss: 0.1150 - val_accuracy: 0.9750
# Epoch 80/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1416 - accuracy: 0.9625 - val_loss: 0.1242 - val_accuracy: 0.9875
# Epoch 81/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1262 - accuracy: 0.9688 - val_loss: 0.1128 - val_accuracy: 0.9750
# Epoch 82/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1014 - accuracy: 0.9625 - val_loss: 0.3133 - val_accuracy: 0.8875
# Epoch 83/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1352 - accuracy: 0.9500 - val_loss: 0.1480 - val_accuracy: 0.9500
# Epoch 84/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1434 - accuracy: 0.9500 - val_loss: 0.1408 - val_accuracy: 0.9500
# Epoch 85/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1276 - accuracy: 0.9563 - val_loss: 0.1690 - val_accuracy: 0.9375
# Epoch 86/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1300 - accuracy: 0.9625 - val_loss: 0.1617 - val_accuracy: 0.9750
# Epoch 87/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1212 - accuracy: 0.9563 - val_loss: 0.1712 - val_accuracy: 0.9625
# Epoch 88/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1021 - accuracy: 0.9563 - val_loss: 0.1131 - val_accuracy: 0.9500
# Epoch 89/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1139 - accuracy: 0.9688 - val_loss: 0.1258 - val_accuracy: 0.9500
# Epoch 90/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0892 - accuracy: 0.9812 - val_loss: 0.1250 - val_accuracy: 0.9625
# Epoch 91/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1067 - accuracy: 0.9625 - val_loss: 0.1847 - val_accuracy: 0.9250
# Epoch 92/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1354 - accuracy: 0.9312 - val_loss: 0.1699 - val_accuracy: 0.9625
# Epoch 93/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1007 - accuracy: 0.9688 - val_loss: 0.1091 - val_accuracy: 0.9750
# Epoch 94/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0886 - accuracy: 0.9750 - val_loss: 0.0908 - val_accuracy: 0.9625
# Epoch 95/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1068 - accuracy: 0.9625 - val_loss: 0.1038 - val_accuracy: 0.9625
# Epoch 96/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1043 - accuracy: 0.9688 - val_loss: 0.1119 - val_accuracy: 0.9625
# Epoch 97/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0925 - accuracy: 0.9750 - val_loss: 0.1947 - val_accuracy: 0.9625
# Epoch 98/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0880 - accuracy: 0.9812 - val_loss: 0.1162 - val_accuracy: 0.9750
# Epoch 99/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0842 - accuracy: 0.9688 - val_loss: 0.1008 - val_accuracy: 0.9625
# Epoch 100/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0938 - accuracy: 0.9688 - val_loss: 0.1066 - val_accuracy: 0.9625

# %%
model4, history4 = create_model(8, 4, 100)
# Out:
# Epoch 1/100
# 160/160 [==============================] - 1s 4ms/step - loss: 2.0709 - accuracy: 0.1312 - val_loss: 2.0563 - val_accuracy: 0.1000
# Epoch 2/100
# 160/160 [==============================] - 0s 3ms/step - loss: 2.0508 - accuracy: 0.1437 - val_loss: 2.0361 - val_accuracy: 0.1000
# Epoch 3/100
# 160/160 [==============================] - 1s 3ms/step - loss: 2.0256 - accuracy: 0.1562 - val_loss: 2.0157 - val_accuracy: 0.1000
# Epoch 4/100
# 160/160 [==============================] - 1s 4ms/step - loss: 2.0008 - accuracy: 0.1437 - val_loss: 1.9832 - val_accuracy: 0.1000
# Epoch 5/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.9535 - accuracy: 0.1437 - val_loss: 1.9475 - val_accuracy: 0.1000
# Epoch 6/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.9213 - accuracy: 0.2313 - val_loss: 1.9172 - val_accuracy: 0.1750
# Epoch 7/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.8752 - accuracy: 0.1750 - val_loss: 1.8894 - val_accuracy: 0.2375
# Epoch 8/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.8399 - accuracy: 0.2375 - val_loss: 1.8753 - val_accuracy: 0.2500
# Epoch 9/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.8084 - accuracy: 0.2313 - val_loss: 1.8350 - val_accuracy: 0.2125
# Epoch 10/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.7841 - accuracy: 0.2688 - val_loss: 1.8284 - val_accuracy: 0.2500
# Epoch 11/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.7608 - accuracy: 0.2625 - val_loss: 1.8032 - val_accuracy: 0.2000
# Epoch 12/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.7352 - accuracy: 0.2562 - val_loss: 1.7797 - val_accuracy: 0.2500
# Epoch 13/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.7163 - accuracy: 0.2625 - val_loss: 1.7652 - val_accuracy: 0.2250
# Epoch 14/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.6991 - accuracy: 0.2500 - val_loss: 1.7460 - val_accuracy: 0.2375
# Epoch 15/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.6807 - accuracy: 0.2562 - val_loss: 1.7352 - val_accuracy: 0.2250
# Epoch 16/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.6528 - accuracy: 0.2937 - val_loss: 1.7130 - val_accuracy: 0.2500
# Epoch 17/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.6373 - accuracy: 0.2688 - val_loss: 1.7027 - val_accuracy: 0.2375
# Epoch 18/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.6254 - accuracy: 0.3000 - val_loss: 1.6987 - val_accuracy: 0.2250
# Epoch 19/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.6104 - accuracy: 0.3187 - val_loss: 1.6712 - val_accuracy: 0.2625
# Epoch 20/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.5884 - accuracy: 0.3313 - val_loss: 1.6566 - val_accuracy: 0.2500
# Epoch 21/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.5758 - accuracy: 0.3375 - val_loss: 1.6458 - val_accuracy: 0.2625
# Epoch 22/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.5563 - accuracy: 0.3375 - val_loss: 1.6282 - val_accuracy: 0.2625
# Epoch 23/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.5399 - accuracy: 0.3625 - val_loss: 1.6126 - val_accuracy: 0.2750
# Epoch 24/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.5363 - accuracy: 0.3688 - val_loss: 1.6056 - val_accuracy: 0.2625
# Epoch 25/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.5142 - accuracy: 0.3625 - val_loss: 1.5932 - val_accuracy: 0.2875
# Epoch 26/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.5046 - accuracy: 0.3875 - val_loss: 1.5771 - val_accuracy: 0.2625
# Epoch 27/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.4880 - accuracy: 0.3625 - val_loss: 1.5904 - val_accuracy: 0.3875
# Epoch 28/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.4814 - accuracy: 0.3938 - val_loss: 1.5622 - val_accuracy: 0.2625
# Epoch 29/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.4695 - accuracy: 0.4000 - val_loss: 1.5457 - val_accuracy: 0.2625
# Epoch 30/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.4484 - accuracy: 0.4000 - val_loss: 1.5322 - val_accuracy: 0.3125
# Epoch 31/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.4414 - accuracy: 0.4187 - val_loss: 1.5322 - val_accuracy: 0.3875
# Epoch 32/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.4310 - accuracy: 0.4313 - val_loss: 1.5845 - val_accuracy: 0.2375
# Epoch 33/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.4219 - accuracy: 0.4437 - val_loss: 1.5170 - val_accuracy: 0.3875
# Epoch 34/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.4111 - accuracy: 0.4500 - val_loss: 1.4974 - val_accuracy: 0.3875
# Epoch 35/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.3999 - accuracy: 0.4500 - val_loss: 1.4890 - val_accuracy: 0.2875
# Epoch 36/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.3889 - accuracy: 0.4437 - val_loss: 1.4748 - val_accuracy: 0.3125
# Epoch 37/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.3832 - accuracy: 0.4437 - val_loss: 1.4653 - val_accuracy: 0.3875
# Epoch 38/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.3701 - accuracy: 0.4563 - val_loss: 1.4626 - val_accuracy: 0.3875
# Epoch 39/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.3621 - accuracy: 0.4500 - val_loss: 1.4626 - val_accuracy: 0.2750
# Epoch 40/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.3529 - accuracy: 0.4688 - val_loss: 1.4383 - val_accuracy: 0.3875
# Epoch 41/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.3518 - accuracy: 0.4938 - val_loss: 1.4337 - val_accuracy: 0.3875
# Epoch 42/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.3378 - accuracy: 0.4563 - val_loss: 1.4548 - val_accuracy: 0.4000
# Epoch 43/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.3351 - accuracy: 0.4938 - val_loss: 1.4319 - val_accuracy: 0.4000
# Epoch 44/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.3294 - accuracy: 0.5000 - val_loss: 1.4094 - val_accuracy: 0.3875
# Epoch 45/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.3159 - accuracy: 0.5000 - val_loss: 1.4117 - val_accuracy: 0.3875
# Epoch 46/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.3105 - accuracy: 0.4938 - val_loss: 1.3955 - val_accuracy: 0.4000
# Epoch 47/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.3010 - accuracy: 0.4875 - val_loss: 1.3882 - val_accuracy: 0.3875
# Epoch 48/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.2936 - accuracy: 0.5000 - val_loss: 1.4428 - val_accuracy: 0.3000
# Epoch 49/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.3053 - accuracy: 0.4750 - val_loss: 1.4118 - val_accuracy: 0.3625
# Epoch 50/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.2719 - accuracy: 0.5000 - val_loss: 1.3676 - val_accuracy: 0.3875
# Epoch 51/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.2675 - accuracy: 0.4938 - val_loss: 1.3600 - val_accuracy: 0.4000
# Epoch 52/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.2595 - accuracy: 0.5063 - val_loss: 1.3513 - val_accuracy: 0.4000
# Epoch 53/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.2653 - accuracy: 0.4875 - val_loss: 1.3694 - val_accuracy: 0.4250
# Epoch 54/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.2825 - accuracy: 0.5063 - val_loss: 1.3408 - val_accuracy: 0.4000
# Epoch 55/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.2511 - accuracy: 0.5188 - val_loss: 1.3503 - val_accuracy: 0.4125
# Epoch 56/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.2440 - accuracy: 0.5000 - val_loss: 1.3447 - val_accuracy: 0.4125
# Epoch 57/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.2423 - accuracy: 0.5000 - val_loss: 1.3382 - val_accuracy: 0.3875
# Epoch 58/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.2242 - accuracy: 0.5188 - val_loss: 1.3183 - val_accuracy: 0.4000
# Epoch 59/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.2215 - accuracy: 0.5188 - val_loss: 1.3151 - val_accuracy: 0.4000
# Epoch 60/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.2269 - accuracy: 0.5063 - val_loss: 1.3170 - val_accuracy: 0.4000
# Epoch 61/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.2071 - accuracy: 0.5188 - val_loss: 1.3046 - val_accuracy: 0.4000
# Epoch 62/100
# 160/160 [==============================] - 1s 5ms/step - loss: 1.2118 - accuracy: 0.5250 - val_loss: 1.3064 - val_accuracy: 0.4000
# Epoch 63/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.2051 - accuracy: 0.5000 - val_loss: 1.2975 - val_accuracy: 0.4000
# Epoch 64/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.1939 - accuracy: 0.5250 - val_loss: 1.2984 - val_accuracy: 0.4000
# Epoch 65/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.1816 - accuracy: 0.5250 - val_loss: 1.3098 - val_accuracy: 0.4250
# Epoch 66/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.1838 - accuracy: 0.5312 - val_loss: 1.2935 - val_accuracy: 0.4000
# Epoch 67/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.1815 - accuracy: 0.5125 - val_loss: 1.3172 - val_accuracy: 0.3750
# Epoch 68/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.1764 - accuracy: 0.5188 - val_loss: 1.3208 - val_accuracy: 0.3750
# Epoch 69/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.1778 - accuracy: 0.5188 - val_loss: 1.2746 - val_accuracy: 0.4000
# Epoch 70/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.1615 - accuracy: 0.5250 - val_loss: 1.2750 - val_accuracy: 0.4125
# Epoch 71/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.1644 - accuracy: 0.5312 - val_loss: 1.2865 - val_accuracy: 0.4125
# Epoch 72/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.1645 - accuracy: 0.5375 - val_loss: 1.2856 - val_accuracy: 0.3875
# Epoch 73/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.1662 - accuracy: 0.5125 - val_loss: 1.2599 - val_accuracy: 0.4125
# Epoch 74/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.1566 - accuracy: 0.5188 - val_loss: 1.2509 - val_accuracy: 0.4125
# Epoch 75/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.1386 - accuracy: 0.5312 - val_loss: 1.2514 - val_accuracy: 0.4375
# Epoch 76/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.1391 - accuracy: 0.5375 - val_loss: 1.2706 - val_accuracy: 0.4125
# Epoch 77/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.1272 - accuracy: 0.5312 - val_loss: 1.2408 - val_accuracy: 0.4250
# Epoch 78/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.1314 - accuracy: 0.5250 - val_loss: 1.2370 - val_accuracy: 0.4250
# Epoch 79/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.1238 - accuracy: 0.5188 - val_loss: 1.2343 - val_accuracy: 0.4375
# Epoch 80/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.1249 - accuracy: 0.5312 - val_loss: 1.2305 - val_accuracy: 0.4375
# Epoch 81/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.1184 - accuracy: 0.5562 - val_loss: 1.2277 - val_accuracy: 0.4250
# Epoch 82/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.1251 - accuracy: 0.5312 - val_loss: 1.2255 - val_accuracy: 0.4375
# Epoch 83/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.1234 - accuracy: 0.5375 - val_loss: 1.2172 - val_accuracy: 0.4375
# Epoch 84/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.1181 - accuracy: 0.5312 - val_loss: 1.2219 - val_accuracy: 0.4250
# Epoch 85/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.1030 - accuracy: 0.5375 - val_loss: 1.2261 - val_accuracy: 0.4500
# Epoch 86/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0968 - accuracy: 0.5312 - val_loss: 1.2323 - val_accuracy: 0.4375
# Epoch 87/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0987 - accuracy: 0.5562 - val_loss: 1.2074 - val_accuracy: 0.4375
# Epoch 88/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0989 - accuracy: 0.5312 - val_loss: 1.2046 - val_accuracy: 0.4250
# Epoch 89/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0860 - accuracy: 0.5375 - val_loss: 1.2131 - val_accuracy: 0.4250
# Epoch 90/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0922 - accuracy: 0.5437 - val_loss: 1.1989 - val_accuracy: 0.4375
# Epoch 91/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0954 - accuracy: 0.5312 - val_loss: 1.2027 - val_accuracy: 0.4625
# Epoch 92/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.1047 - accuracy: 0.5250 - val_loss: 1.1947 - val_accuracy: 0.4375
# Epoch 93/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0776 - accuracy: 0.5562 - val_loss: 1.1946 - val_accuracy: 0.4375
# Epoch 94/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0791 - accuracy: 0.5625 - val_loss: 1.1965 - val_accuracy: 0.4500
# Epoch 95/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0673 - accuracy: 0.5688 - val_loss: 1.1858 - val_accuracy: 0.4375
# Epoch 96/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.0779 - accuracy: 0.5562 - val_loss: 1.1960 - val_accuracy: 0.4250
# Epoch 97/100
# 160/160 [==============================] - 1s 6ms/step - loss: 1.0736 - accuracy: 0.5750 - val_loss: 1.1851 - val_accuracy: 0.4375
# Epoch 98/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0716 - accuracy: 0.5562 - val_loss: 1.1816 - val_accuracy: 0.4375
# Epoch 99/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0666 - accuracy: 0.5312 - val_loss: 1.1754 - val_accuracy: 0.4375
# Epoch 100/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0546 - accuracy: 0.5625 - val_loss: 1.1796 - val_accuracy: 0.4250

# %%
models = [model1, model2, model3, model4]
histories = [history1, history2, history3, history4]

# %% [markdown]
# ## Review models' performance

# %%
# increase the size of the graphs. The default size is (6,4).
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
def plot_model_loss(history, title, i):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)
    
    ax = axs[int(i/2), i % 2]
    ax.plot(epochs, loss, 'g.', label='Training loss')
    ax.plot(epochs, val_loss, 'b.', label='Validation loss')
    ax.set_title(title)
#     ax.xlabel('Epochs')
#     ax.ylabel('Loss')
    ax.set(xlabel='Epochs', ylabel='Loss')
    ax.legend()
#     ax.show()

for i in range(4):
    plot_model_loss(histories[i], 'Model '+ str(i+1) + ' train/validate loss', i)

# %%
# increase the size of the graphs. The default size is (6,4).
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
def plot_model_accuracy(history, title, i):
    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    epochs = range(1, len(accuracy) + 1)
    
    ax = axs[int(i/2), i % 2]
    ax.plot(epochs, accuracy, 'g.', label='Training accuracy')
    ax.plot(epochs, val_accuracy, 'b.', label='Validation accuracy')
    ax.set_title(title)
    ax.set(xlabel='Epochs', ylabel='Loss')
    ax.legend()

for i in range(4):
    plot_model_accuracy(histories[i], 'Model '+ str(i+1) + ' accuracy', i)

# %%
models[0](i_test[:1])
# Out:
# <tf.Tensor: shape=(1, 8), dtype=float32, numpy=
# array([[6.1196681e-07, 6.5340009e-09, 1.1179138e-05, 4.1449047e-10,
#         1.9054630e-06, 5.4505636e-04, 9.9533635e-01, 4.1049519e-03]],
#       dtype=float32)>

# %% [markdown]
# ## Verify models with test data

# %%
fig, axs = plt.subplots(2, 2, figsize=(7, 7))
fig.tight_layout(pad=5.0)
def plot_cm(model, title, i):
    predict = model.predict(i_test)
    conf_mat = confusion_matrix(np.argmax(o_test, axis=1), np.argmax(predict, axis=1))
    ax = axs[int(i/2), i % 2]
    sb.heatmap(conf_mat, annot=True, cmap='Blues', fmt='g', cbar=False, ax=ax)
    ax.set_title(title)
    ax.set(xlabel='Actual labels', ylabel='Predicted labels')

for i in range(4):
    plot_cm(models[i], 'Model '+ str(i+1) + ' predict test data', i)
# Out:
# 3/3 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 3ms/step

# %% [markdown]
# ## Produce model file (.tflite)
#
# Output both non-quantized and quantized model files

# %%
def representative_dataset_generator():
 # each scalar value inside a 2D array that is wrapped in a list
 for value in inputs:
     yield [np.array(value, dtype=np.float32, ndmin=2)]



for i, model in enumerate(models):
    TFLITE_FILE = 'tflite/test_complexity/gesture_model_' + str(i+1) + '.tflite'
    TFLITE_FILE_Q = 'tflite/test_complexity/gesture_model_' + str(i+1) + 'q.tflite'
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    tflite_model = converter.convert()
    open(TFLITE_FILE, "wb").write(tflite_model)
    
    converter_q = tf.lite.TFLiteConverter.from_keras_model(model)
    converter_q.optimizations = [tf.lite.Optimize.DEFAULT]
    converter_q.representative_dataset = representative_dataset_generator
    tflite_model_q = converter_q.convert()
    open(TFLITE_FILE_Q, "wb").write(tflite_model_q)
    
    # Review size difference
    basic_model_size = os.path.getsize(TFLITE_FILE)
    print("Basic model{} is {} bytes".format(i, basic_model_size))

    basic_model_size_q = os.path.getsize(TFLITE_FILE_Q)
    print("Quantized model{} is {} bytes".format(i, basic_model_size_q))
# Out:
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpbnov_1so\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpn8z1ut88\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpn8z1ut88\assets
# C:\Users\cheew\anaconda3\envs\tf\lib\site-packages\tensorflow\lite\python\convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# Basic model0 is 57804 bytes
# Quantized model0 is 17072 bytes
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmptwysqap7\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmptwysqap7\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmp5xwh2v1p\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmp5xwh2v1p\assets
# C:\Users\cheew\anaconda3\envs\tf\lib\site-packages\tensorflow\lite\python\convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# Basic model1 is 27948 bytes
# Quantized model1 is 9480 bytes
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpokyt6jq1\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpokyt6jq1\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmp2_ldd7o8\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmp2_ldd7o8\assets
# C:\Users\cheew\anaconda3\envs\tf\lib\site-packages\tensorflow\lite\python\convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# Basic model2 is 14540 bytes
# Quantized model2 is 6056 bytes
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmph5izvocx\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmph5izvocx\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmp68gkdw19\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmp68gkdw19\assets
# Basic model3 is 8244 bytes
# Quantized model3 is 4464 bytes
# C:\Users\cheew\anaconda3\envs\tf\lib\site-packages\tensorflow\lite\python\convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "

# %% [markdown]
# ## Verify the interpreter (.tflite)

# %%
fig, axs = plt.subplots(2, 2, figsize=(7, 7))
fig.tight_layout(pad=5.0)

for i in range(4):
    TFLITE_FILE = 'tflite/test_complexity/gesture_model_' + str(i+1) + '.tflite'
    model = tf.lite.Interpreter(TFLITE_FILE)
    model.allocate_tensors()
    model_input_index = model.get_input_details()[0]['index']
    model_output_index = model.get_output_details()[0]['index']
    predict = []
    for j in i_test:
    # write the value to the input tensor
        i_tensor = tf.convert_to_tensor([j], dtype=tf.float32)
        model.set_tensor(model_input_index, i_tensor)
        # run inference
        model.invoke()
        # read the prediction from the output tensor
        predict.append(model.get_tensor(model_output_index)[0])
        
    ax = axs[int(i/2), i % 2]
    conf_mat = confusion_matrix(np.argmax(o_test, axis=1), np.argmax(predict, axis=1))
    ax = axs[int(i/2), i % 2]
    sb.heatmap(conf_mat, annot=True, cmap='Blues', fmt='g', cbar=False, ax=ax)
    ax.set_title("Model " + str(i+1))
    ax.set(xlabel='Actual labels', ylabel='Predicted labels')

# %% [markdown]
# ## Verify the quantized interpreter (.tflite)

# %%
fig, axs = plt.subplots(2, 2, figsize=(7, 7))
fig.tight_layout(pad=5.0)

for i in range(4):
    TFLITE_FILE_Q = 'tflite/test_complexity/gesture_model_' + str(i+1) + 'q.tflite'
    model = tf.lite.Interpreter(TFLITE_FILE_Q)
    model.allocate_tensors()
    model_input_index = model.get_input_details()[0]['index']
    model_output_index = model.get_output_details()[0]['index']
    predict = []
    for j in i_test:
    # write the value to the input tensor
        i_tensor = tf.convert_to_tensor([j], dtype=tf.float32)
        model.set_tensor(model_input_index, i_tensor)
        # run inference
        model.invoke()
        # read the prediction from the output tensor
        predict.append(model.get_tensor(model_output_index)[0])
        
    ax = axs[int(i/2), i % 2]
    conf_mat = confusion_matrix(np.argmax(o_test, axis=1), np.argmax(predict, axis=1))
    ax = axs[int(i/2), i % 2]
    sb.heatmap(conf_mat, annot=True, cmap='Blues', fmt='g', cbar=False, ax=ax)
    ax.set_title("Model " + str(i+1))
    ax.set(xlabel='Actual labels', ylabel='Predicted labels')

# %% [markdown]
# ## Produce the model header file

# %%
# to run below command, ensure jupyter notebook is launched under bash terminal (eg. git bash, linux terminal)

for i in range(4):
    TFLITE_FILE = 'tflite/test_complexity/gesture_model_' + str(i+1) + '.tflite'
    TFLITE_FILE_Q = 'tflite/test_complexity/gesture_model_' + str(i+1) + 'q.tflite'
    
    HEADER_FILE = '../ble_client/test_complexity/gesture_model_'+str(i+1)+'.h'
    HEADER_FILE_Q = '../ble_client/test_complexity/gesture_model_'+str(i+1)+'q.h'
    # based model header file
    str1 = "const unsigned char {} [] = {{".format('gesture_model')
    str2 = "};"

    # !echo {str1}  > {HEADER_FILE}
    # !cat {TFLITE_FILE} | xxd -i >> {HEADER_FILE}
    # !echo {str2} >> {HEADER_FILE}

    # quantized model header file
    str3 = "const unsigned char {} [] = {{".format('gesture_model_q')

    # !echo {str3}  > {HEADER_FILE_Q}
    # !cat {TFLITE_FILE_Q} | xxd -i >> {HEADER_FILE_Q}
    # !echo {str2} >> {HEADER_FILE_Q}
