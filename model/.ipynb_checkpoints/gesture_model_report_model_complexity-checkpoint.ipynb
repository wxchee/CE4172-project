# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import math
import pandas as pd

from sklearn.metrics import confusion_matrix
import seaborn as sb

# %%
# define constant

FOLDER = 'datas/s40d30t1.6/'
GESTURES = ["topl", "twistl", "side", "downl", "twistr", "topr", "downr","unknown"]

DATA_POINT_PER_GESTURE = 30


SEED = 1337
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Process data

# %%
inputs = []
outputs = []

ONE_HOTS = np.eye(len(GESTURES))

for i in range(len(GESTURES)):
    g = GESTURES[i]
    print(f"Processing {i} for gesture '{g}'.")
    
    output = ONE_HOTS[i]
    
    df = pd.read_csv(FOLDER + g + '.csv')
    num_recordings = int(df.shape[0] / DATA_POINT_PER_GESTURE)
    
    for j in range(num_recordings):
        tensor = []
        
        for k in range(DATA_POINT_PER_GESTURE):
            kk = j * DATA_POINT_PER_GESTURE + k
            
            tensor += [
                df['aX'][kk],
                df['aY'][kk],
                df['aZ'][kk],
                df['gX'][kk],
                df['gY'][kk],
                df['gZ'][kk],
#                 df['mX'][kk],
#                 df['mY'][kk],
#                 df['mZ'][kk],
            ]
            
        inputs.append(tensor)
        outputs.append(output)
# Out:
# Processing 0 for gesture 'topl'.
# Processing 1 for gesture 'twistl'.
# Processing 2 for gesture 'side'.
# Processing 3 for gesture 'downl'.
# Processing 4 for gesture 'twistr'.
# Processing 5 for gesture 'topr'.
# Processing 6 for gesture 'downr'.
# Processing 7 for gesture 'unknown'.

# %%
# display(pd.DataFrame(inputs))

# %% [markdown]
# ## Create train/validate/test datas

# %%
rdm_index = np.arange(len(inputs))
np.random.shuffle(rdm_index)

inputs = np.array(inputs)[rdm_index]
outputs = np.array(outputs)[rdm_index]

TRAIN_SPLIT = int(0.5 * len(inputs))
TEST_SPLIT = int(TRAIN_SPLIT + 0.25 * len(inputs))

i_train, i_validate, i_test = np.split(inputs, [TRAIN_SPLIT, TEST_SPLIT])
o_train, o_validate, o_test = np.split(outputs, [TRAIN_SPLIT, TEST_SPLIT])

# do this if data type invalid
i_train = tf.convert_to_tensor(i_train, dtype=tf.float32)
o_train = tf.convert_to_tensor(o_train, dtype=tf.float32)

i_validate = tf.convert_to_tensor(i_validate, dtype=tf.float32)
o_validate = tf.convert_to_tensor(o_validate, dtype=tf.float32)

i_test = tf.convert_to_tensor(i_test, dtype=tf.float32)

# %% [markdown]
# ## Build and train model

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']="TRUE"

EPOCHS=150

# %%
def create_model(n1, n2, epoch=EPOCHS):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(n1, activation='relu'),
        tf.keras.layers.Dense(n2, activation='relu'),
        tf.keras.layers.Dense(len(GESTURES), activation='softmax')
    ])
    
    model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy(), metrics=['accuracy'])
    history = model.fit(i_train, o_train, epochs=epoch, batch_size=1,validation_data=(i_validate, o_validate))
    
    return model, history

# %%
model1, history1 = create_model(64, 32, 40)
# Out:
# Epoch 1/40
# 160/160 [==============================] - 2s 6ms/step - loss: 2.1255 - accuracy: 0.1063 - val_loss: 2.0423 - val_accuracy: 0.1375
# Epoch 2/40
# 160/160 [==============================] - 1s 4ms/step - loss: 2.0037 - accuracy: 0.2625 - val_loss: 1.9354 - val_accuracy: 0.4750
# Epoch 3/40
# 160/160 [==============================] - 1s 3ms/step - loss: 1.8749 - accuracy: 0.3812 - val_loss: 1.7978 - val_accuracy: 0.4250
# Epoch 4/40
# 160/160 [==============================] - 0s 3ms/step - loss: 1.6367 - accuracy: 0.4812 - val_loss: 1.5728 - val_accuracy: 0.5250
# Epoch 5/40
# 160/160 [==============================] - 1s 3ms/step - loss: 1.2788 - accuracy: 0.6250 - val_loss: 1.2202 - val_accuracy: 0.6750
# Epoch 6/40
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0194 - accuracy: 0.6687 - val_loss: 1.1244 - val_accuracy: 0.6250
# Epoch 7/40
# 160/160 [==============================] - 0s 3ms/step - loss: 0.9002 - accuracy: 0.7063 - val_loss: 0.8961 - val_accuracy: 0.6625
# Epoch 8/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.7836 - accuracy: 0.7563 - val_loss: 0.8078 - val_accuracy: 0.7000
# Epoch 9/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.6702 - accuracy: 0.7688 - val_loss: 0.7391 - val_accuracy: 0.7625
# Epoch 10/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.6317 - accuracy: 0.8062 - val_loss: 0.6508 - val_accuracy: 0.8000
# Epoch 11/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.5764 - accuracy: 0.8000 - val_loss: 0.5881 - val_accuracy: 0.8875
# Epoch 12/40
# 160/160 [==============================] - 1s 4ms/step - loss: 0.4974 - accuracy: 0.8313 - val_loss: 0.6608 - val_accuracy: 0.7625
# Epoch 13/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4707 - accuracy: 0.8750 - val_loss: 0.6343 - val_accuracy: 0.7250
# Epoch 14/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4589 - accuracy: 0.8250 - val_loss: 0.4547 - val_accuracy: 0.8750
# Epoch 15/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3977 - accuracy: 0.8813 - val_loss: 0.4524 - val_accuracy: 0.8625
# Epoch 16/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3558 - accuracy: 0.8813 - val_loss: 0.6654 - val_accuracy: 0.7625
# Epoch 17/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3551 - accuracy: 0.9000 - val_loss: 0.3856 - val_accuracy: 0.9375
# Epoch 18/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3713 - accuracy: 0.8687 - val_loss: 0.3072 - val_accuracy: 0.9625
# Epoch 19/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3061 - accuracy: 0.9000 - val_loss: 0.3087 - val_accuracy: 0.9625
# Epoch 20/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2864 - accuracy: 0.8875 - val_loss: 0.3007 - val_accuracy: 0.9250
# Epoch 21/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2596 - accuracy: 0.9062 - val_loss: 0.3329 - val_accuracy: 0.8500
# Epoch 22/40
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2528 - accuracy: 0.9250 - val_loss: 0.2563 - val_accuracy: 0.9375
# Epoch 23/40
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2504 - accuracy: 0.8938 - val_loss: 0.2624 - val_accuracy: 0.9125
# Epoch 24/40
# 160/160 [==============================] - 1s 4ms/step - loss: 0.2035 - accuracy: 0.9563 - val_loss: 0.2262 - val_accuracy: 0.9375
# Epoch 25/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1889 - accuracy: 0.9625 - val_loss: 0.1728 - val_accuracy: 0.9375
# Epoch 26/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1990 - accuracy: 0.9375 - val_loss: 0.1695 - val_accuracy: 0.9625
# Epoch 27/40
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1765 - accuracy: 0.9500 - val_loss: 0.2396 - val_accuracy: 0.9000
# Epoch 28/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1978 - accuracy: 0.9187 - val_loss: 0.1392 - val_accuracy: 0.9625
# Epoch 29/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1547 - accuracy: 0.9688 - val_loss: 0.1563 - val_accuracy: 0.9750
# Epoch 30/40
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1424 - accuracy: 0.9563 - val_loss: 0.2549 - val_accuracy: 0.9500
# Epoch 31/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1631 - accuracy: 0.9438 - val_loss: 0.1349 - val_accuracy: 0.9875
# Epoch 32/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1469 - accuracy: 0.9563 - val_loss: 0.1131 - val_accuracy: 1.0000
# Epoch 33/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1172 - accuracy: 0.9563 - val_loss: 0.1308 - val_accuracy: 1.0000
# Epoch 34/40
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1113 - accuracy: 0.9688 - val_loss: 0.1436 - val_accuracy: 0.9750
# Epoch 35/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1245 - accuracy: 0.9563 - val_loss: 0.1830 - val_accuracy: 0.9250
# Epoch 36/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1325 - accuracy: 0.9563 - val_loss: 0.1026 - val_accuracy: 0.9625
# Epoch 37/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1166 - accuracy: 0.9625 - val_loss: 0.0780 - val_accuracy: 1.0000
# Epoch 38/40
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1139 - accuracy: 0.9563 - val_loss: 0.1768 - val_accuracy: 0.9250
# Epoch 39/40
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0899 - accuracy: 0.9750 - val_loss: 0.0804 - val_accuracy: 0.9750
# Epoch 40/40
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1131 - accuracy: 0.9438 - val_loss: 0.0932 - val_accuracy: 1.0000

# %%
model2, history2 = create_model(32, 16, 60)
# Out:
# Epoch 1/60
# 160/160 [==============================] - 1s 5ms/step - loss: 2.0941 - accuracy: 0.1187 - val_loss: 2.0681 - val_accuracy: 0.0875
# Epoch 2/60
# 160/160 [==============================] - 1s 3ms/step - loss: 2.0612 - accuracy: 0.1500 - val_loss: 2.0687 - val_accuracy: 0.2000
# Epoch 3/60
# 160/160 [==============================] - 1s 3ms/step - loss: 2.0352 - accuracy: 0.2000 - val_loss: 2.0503 - val_accuracy: 0.0875
# Epoch 4/60
# 160/160 [==============================] - 1s 3ms/step - loss: 1.9965 - accuracy: 0.2313 - val_loss: 2.0197 - val_accuracy: 0.1125
# Epoch 5/60
# 160/160 [==============================] - 1s 4ms/step - loss: 1.9247 - accuracy: 0.2500 - val_loss: 1.9748 - val_accuracy: 0.1625
# Epoch 6/60
# 160/160 [==============================] - 1s 3ms/step - loss: 1.8213 - accuracy: 0.2875 - val_loss: 1.9785 - val_accuracy: 0.1625
# Epoch 7/60
# 160/160 [==============================] - 1s 7ms/step - loss: 1.7008 - accuracy: 0.3125 - val_loss: 1.7702 - val_accuracy: 0.2750
# Epoch 8/60
# 160/160 [==============================] - 1s 4ms/step - loss: 1.5981 - accuracy: 0.3438 - val_loss: 1.6662 - val_accuracy: 0.3125
# Epoch 9/60
# 160/160 [==============================] - 1s 4ms/step - loss: 1.4765 - accuracy: 0.3438 - val_loss: 1.5901 - val_accuracy: 0.3250
# Epoch 10/60
# 160/160 [==============================] - 1s 3ms/step - loss: 1.3952 - accuracy: 0.4375 - val_loss: 1.4936 - val_accuracy: 0.5250
# Epoch 11/60
# 160/160 [==============================] - 1s 4ms/step - loss: 1.2937 - accuracy: 0.5625 - val_loss: 1.3748 - val_accuracy: 0.4000
# Epoch 12/60
# 160/160 [==============================] - 1s 5ms/step - loss: 1.2104 - accuracy: 0.6125 - val_loss: 1.3361 - val_accuracy: 0.5500
# Epoch 13/60
# 160/160 [==============================] - 1s 3ms/step - loss: 1.1408 - accuracy: 0.6250 - val_loss: 1.2385 - val_accuracy: 0.5875
# Epoch 14/60
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0688 - accuracy: 0.6313 - val_loss: 1.1192 - val_accuracy: 0.6500
# Epoch 15/60
# 160/160 [==============================] - 1s 4ms/step - loss: 1.0276 - accuracy: 0.6500 - val_loss: 1.1048 - val_accuracy: 0.7125
# Epoch 16/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.9443 - accuracy: 0.6875 - val_loss: 1.0086 - val_accuracy: 0.6625
# Epoch 17/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.9068 - accuracy: 0.7125 - val_loss: 0.9458 - val_accuracy: 0.8125
# Epoch 18/60
# 160/160 [==============================] - 1s 4ms/step - loss: 0.8890 - accuracy: 0.7000 - val_loss: 0.9104 - val_accuracy: 0.7500
# Epoch 19/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.8315 - accuracy: 0.7625 - val_loss: 0.8702 - val_accuracy: 0.7250
# Epoch 20/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.8031 - accuracy: 0.7250 - val_loss: 0.8335 - val_accuracy: 0.8375
# Epoch 21/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.7731 - accuracy: 0.7375 - val_loss: 0.8120 - val_accuracy: 0.8500
# Epoch 22/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.7397 - accuracy: 0.7937 - val_loss: 0.7718 - val_accuracy: 0.8625
# Epoch 23/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.7154 - accuracy: 0.7688 - val_loss: 0.8289 - val_accuracy: 0.6500
# Epoch 24/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.6941 - accuracy: 0.7875 - val_loss: 0.7145 - val_accuracy: 0.8625
# Epoch 25/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.6698 - accuracy: 0.7875 - val_loss: 0.7232 - val_accuracy: 0.7875
# Epoch 26/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.6516 - accuracy: 0.8250 - val_loss: 0.6578 - val_accuracy: 0.8375
# Epoch 27/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.6428 - accuracy: 0.7937 - val_loss: 0.8229 - val_accuracy: 0.6000
# Epoch 28/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.6062 - accuracy: 0.8313 - val_loss: 0.6327 - val_accuracy: 0.8375
# Epoch 29/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.6109 - accuracy: 0.8375 - val_loss: 0.6151 - val_accuracy: 0.8125
# Epoch 30/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.5675 - accuracy: 0.8375 - val_loss: 0.5743 - val_accuracy: 0.8875
# Epoch 31/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.5507 - accuracy: 0.8375 - val_loss: 0.7072 - val_accuracy: 0.7750
# Epoch 32/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.5333 - accuracy: 0.8625 - val_loss: 0.5514 - val_accuracy: 0.9125
# Epoch 33/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.5219 - accuracy: 0.8687 - val_loss: 0.5322 - val_accuracy: 0.9125
# Epoch 34/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4976 - accuracy: 0.8750 - val_loss: 0.5434 - val_accuracy: 0.8250
# Epoch 35/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4965 - accuracy: 0.8562 - val_loss: 0.5169 - val_accuracy: 0.8875
# Epoch 36/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4782 - accuracy: 0.8625 - val_loss: 0.4836 - val_accuracy: 0.9125
# Epoch 37/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4731 - accuracy: 0.8562 - val_loss: 0.5092 - val_accuracy: 0.8250
# Epoch 38/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4740 - accuracy: 0.8438 - val_loss: 0.5140 - val_accuracy: 0.8500
# Epoch 39/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4596 - accuracy: 0.8875 - val_loss: 0.4836 - val_accuracy: 0.8625
# Epoch 40/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4727 - accuracy: 0.8625 - val_loss: 0.4377 - val_accuracy: 0.9000
# Epoch 41/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4297 - accuracy: 0.8562 - val_loss: 0.4295 - val_accuracy: 0.9000
# Epoch 42/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4059 - accuracy: 0.8687 - val_loss: 0.4488 - val_accuracy: 0.8750
# Epoch 43/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3970 - accuracy: 0.9062 - val_loss: 0.4818 - val_accuracy: 0.8375
# Epoch 44/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4040 - accuracy: 0.8875 - val_loss: 0.4280 - val_accuracy: 0.9250
# Epoch 45/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4036 - accuracy: 0.8813 - val_loss: 0.6477 - val_accuracy: 0.7375
# Epoch 46/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3830 - accuracy: 0.9000 - val_loss: 0.4303 - val_accuracy: 0.9000
# Epoch 47/60
# 160/160 [==============================] - 1s 4ms/step - loss: 0.3825 - accuracy: 0.8875 - val_loss: 0.5264 - val_accuracy: 0.7875
# Epoch 48/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3932 - accuracy: 0.8687 - val_loss: 0.3899 - val_accuracy: 0.9125
# Epoch 49/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3692 - accuracy: 0.8938 - val_loss: 0.4422 - val_accuracy: 0.8750
# Epoch 50/60
# 160/160 [==============================] - 1s 4ms/step - loss: 0.3592 - accuracy: 0.8938 - val_loss: 0.3961 - val_accuracy: 0.9000
# Epoch 51/60
# 160/160 [==============================] - 1s 4ms/step - loss: 0.3720 - accuracy: 0.8938 - val_loss: 0.3900 - val_accuracy: 0.9250
# Epoch 52/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3662 - accuracy: 0.8750 - val_loss: 0.3832 - val_accuracy: 0.8875
# Epoch 53/60
# 160/160 [==============================] - 1s 4ms/step - loss: 0.3603 - accuracy: 0.9000 - val_loss: 0.3712 - val_accuracy: 0.9250
# Epoch 54/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3395 - accuracy: 0.8750 - val_loss: 0.3864 - val_accuracy: 0.8750
# Epoch 55/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3383 - accuracy: 0.9062 - val_loss: 0.4117 - val_accuracy: 0.9000
# Epoch 56/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3547 - accuracy: 0.8875 - val_loss: 0.3586 - val_accuracy: 0.9250
# Epoch 57/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3099 - accuracy: 0.8875 - val_loss: 0.3694 - val_accuracy: 0.9000
# Epoch 58/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3183 - accuracy: 0.9125 - val_loss: 0.3950 - val_accuracy: 0.8625
# Epoch 59/60
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3049 - accuracy: 0.9187 - val_loss: 0.3675 - val_accuracy: 0.9125
# Epoch 60/60
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3037 - accuracy: 0.9125 - val_loss: 0.3498 - val_accuracy: 0.9000

# %%
model3, history3 = create_model(16, 8, 100)
# Out:
# Epoch 1/100
# 160/160 [==============================] - 2s 5ms/step - loss: 2.0970 - accuracy: 0.1562 - val_loss: 2.0170 - val_accuracy: 0.1625
# Epoch 2/100
# 160/160 [==============================] - 1s 3ms/step - loss: 2.0062 - accuracy: 0.1625 - val_loss: 1.9923 - val_accuracy: 0.2250
# Epoch 3/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.9246 - accuracy: 0.2188 - val_loss: 1.9107 - val_accuracy: 0.1125
# Epoch 4/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.8426 - accuracy: 0.2375 - val_loss: 1.8407 - val_accuracy: 0.3625
# Epoch 5/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.6985 - accuracy: 0.3125 - val_loss: 1.7937 - val_accuracy: 0.4750
# Epoch 6/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.5403 - accuracy: 0.4812 - val_loss: 1.5606 - val_accuracy: 0.5125
# Epoch 7/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.3735 - accuracy: 0.5500 - val_loss: 1.3916 - val_accuracy: 0.5250
# Epoch 8/100
# 160/160 [==============================] - 0s 3ms/step - loss: 1.2467 - accuracy: 0.5813 - val_loss: 1.2344 - val_accuracy: 0.5375
# Epoch 9/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0938 - accuracy: 0.6500 - val_loss: 1.0916 - val_accuracy: 0.6000
# Epoch 10/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.9858 - accuracy: 0.7000 - val_loss: 0.9985 - val_accuracy: 0.6375
# Epoch 11/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.9028 - accuracy: 0.7437 - val_loss: 0.9457 - val_accuracy: 0.6500
# Epoch 12/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.8320 - accuracy: 0.8000 - val_loss: 0.8743 - val_accuracy: 0.6375
# Epoch 13/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.7766 - accuracy: 0.8313 - val_loss: 0.8707 - val_accuracy: 0.6375
# Epoch 14/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.7229 - accuracy: 0.8062 - val_loss: 0.7829 - val_accuracy: 0.6625
# Epoch 15/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.6847 - accuracy: 0.8375 - val_loss: 0.7936 - val_accuracy: 0.6500
# Epoch 16/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.6321 - accuracy: 0.8250 - val_loss: 0.8049 - val_accuracy: 0.7500
# Epoch 17/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.5994 - accuracy: 0.8313 - val_loss: 0.6535 - val_accuracy: 0.8250
# Epoch 18/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.5966 - accuracy: 0.8500 - val_loss: 0.6099 - val_accuracy: 0.8500
# Epoch 19/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.5345 - accuracy: 0.8813 - val_loss: 0.6388 - val_accuracy: 0.7875
# Epoch 20/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.5570 - accuracy: 0.8687 - val_loss: 0.6508 - val_accuracy: 0.8000
# Epoch 21/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4846 - accuracy: 0.8938 - val_loss: 0.5645 - val_accuracy: 0.8250
# Epoch 22/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4587 - accuracy: 0.9125 - val_loss: 0.5353 - val_accuracy: 0.8500
# Epoch 23/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4371 - accuracy: 0.9187 - val_loss: 0.4855 - val_accuracy: 0.8500
# Epoch 24/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4236 - accuracy: 0.8938 - val_loss: 0.4614 - val_accuracy: 0.8750
# Epoch 25/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3988 - accuracy: 0.9375 - val_loss: 0.4454 - val_accuracy: 0.8375
# Epoch 26/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3777 - accuracy: 0.9250 - val_loss: 0.4174 - val_accuracy: 0.9125
# Epoch 27/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3701 - accuracy: 0.9000 - val_loss: 0.5675 - val_accuracy: 0.7500
# Epoch 28/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3592 - accuracy: 0.9250 - val_loss: 0.4016 - val_accuracy: 0.8750
# Epoch 29/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3354 - accuracy: 0.9438 - val_loss: 0.3781 - val_accuracy: 0.8750
# Epoch 30/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3154 - accuracy: 0.9438 - val_loss: 0.3506 - val_accuracy: 0.9125
# Epoch 31/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3029 - accuracy: 0.9375 - val_loss: 0.3427 - val_accuracy: 0.9125
# Epoch 32/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2838 - accuracy: 0.9500 - val_loss: 0.3239 - val_accuracy: 0.9125
# Epoch 33/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2700 - accuracy: 0.9500 - val_loss: 0.2971 - val_accuracy: 0.9000
# Epoch 34/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2618 - accuracy: 0.9375 - val_loss: 0.3173 - val_accuracy: 0.9125
# Epoch 35/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2736 - accuracy: 0.9187 - val_loss: 0.2940 - val_accuracy: 0.9250
# Epoch 36/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2462 - accuracy: 0.9375 - val_loss: 0.2551 - val_accuracy: 0.9250
# Epoch 37/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2560 - accuracy: 0.9438 - val_loss: 0.2583 - val_accuracy: 0.9375
# Epoch 38/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2394 - accuracy: 0.9500 - val_loss: 0.2581 - val_accuracy: 0.9250
# Epoch 39/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2273 - accuracy: 0.9500 - val_loss: 0.3199 - val_accuracy: 0.9375
# Epoch 40/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2411 - accuracy: 0.9500 - val_loss: 0.2268 - val_accuracy: 0.9250
# Epoch 41/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2211 - accuracy: 0.9563 - val_loss: 0.2268 - val_accuracy: 0.9250
# Epoch 42/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1861 - accuracy: 0.9563 - val_loss: 0.2722 - val_accuracy: 0.9250
# Epoch 43/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.1932 - accuracy: 0.9500 - val_loss: 0.2298 - val_accuracy: 0.9625
# Epoch 44/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1972 - accuracy: 0.9438 - val_loss: 0.2267 - val_accuracy: 0.9625
# Epoch 45/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1899 - accuracy: 0.9500 - val_loss: 0.2453 - val_accuracy: 0.9250
# Epoch 46/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2151 - accuracy: 0.9312 - val_loss: 0.2403 - val_accuracy: 0.9000
# Epoch 47/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1791 - accuracy: 0.9625 - val_loss: 0.1954 - val_accuracy: 0.9625
# Epoch 48/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1739 - accuracy: 0.9500 - val_loss: 0.2031 - val_accuracy: 0.9375
# Epoch 49/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1476 - accuracy: 0.9750 - val_loss: 0.1862 - val_accuracy: 0.9500
# Epoch 50/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1584 - accuracy: 0.9500 - val_loss: 0.1839 - val_accuracy: 0.9875
# Epoch 51/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1722 - accuracy: 0.9500 - val_loss: 0.2517 - val_accuracy: 0.9250
# Epoch 52/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1718 - accuracy: 0.9563 - val_loss: 0.1687 - val_accuracy: 0.9500
# Epoch 53/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1646 - accuracy: 0.9688 - val_loss: 0.1571 - val_accuracy: 0.9500
# Epoch 54/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1471 - accuracy: 0.9625 - val_loss: 0.1592 - val_accuracy: 0.9500
# Epoch 55/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1502 - accuracy: 0.9563 - val_loss: 0.1977 - val_accuracy: 0.9250
# Epoch 56/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1537 - accuracy: 0.9625 - val_loss: 0.1743 - val_accuracy: 0.9375
# Epoch 57/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1299 - accuracy: 0.9500 - val_loss: 0.1796 - val_accuracy: 0.9250
# Epoch 58/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1609 - accuracy: 0.9500 - val_loss: 0.1867 - val_accuracy: 0.9250
# Epoch 59/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1281 - accuracy: 0.9750 - val_loss: 0.1350 - val_accuracy: 0.9750
# Epoch 60/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1254 - accuracy: 0.9563 - val_loss: 0.1265 - val_accuracy: 0.9750
# Epoch 61/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1351 - accuracy: 0.9688 - val_loss: 0.1268 - val_accuracy: 0.9750
# Epoch 62/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1370 - accuracy: 0.9625 - val_loss: 0.1193 - val_accuracy: 0.9750
# Epoch 63/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1221 - accuracy: 0.9688 - val_loss: 0.1713 - val_accuracy: 0.9625
# Epoch 64/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1306 - accuracy: 0.9625 - val_loss: 0.1500 - val_accuracy: 0.9750
# Epoch 65/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1283 - accuracy: 0.9750 - val_loss: 0.1250 - val_accuracy: 0.9625
# Epoch 66/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1161 - accuracy: 0.9750 - val_loss: 0.1108 - val_accuracy: 0.9750
# Epoch 67/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1169 - accuracy: 0.9625 - val_loss: 0.1544 - val_accuracy: 0.9500
# Epoch 68/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1240 - accuracy: 0.9625 - val_loss: 0.1346 - val_accuracy: 0.9875
# Epoch 69/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1078 - accuracy: 0.9875 - val_loss: 0.1029 - val_accuracy: 0.9750
# Epoch 70/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1308 - accuracy: 0.9750 - val_loss: 0.1860 - val_accuracy: 0.9375
# Epoch 71/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1060 - accuracy: 0.9625 - val_loss: 0.1013 - val_accuracy: 0.9875
# Epoch 72/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1039 - accuracy: 0.9563 - val_loss: 0.1289 - val_accuracy: 0.9750
# Epoch 73/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1177 - accuracy: 0.9563 - val_loss: 0.1712 - val_accuracy: 0.9250
# Epoch 74/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1110 - accuracy: 0.9563 - val_loss: 0.1143 - val_accuracy: 0.9875
# Epoch 75/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1103 - accuracy: 0.9563 - val_loss: 0.1281 - val_accuracy: 0.9625
# Epoch 76/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1100 - accuracy: 0.9688 - val_loss: 0.0885 - val_accuracy: 0.9875
# Epoch 77/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0923 - accuracy: 0.9750 - val_loss: 0.1339 - val_accuracy: 0.9500
# Epoch 78/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0918 - accuracy: 0.9812 - val_loss: 0.1431 - val_accuracy: 0.9500
# Epoch 79/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0831 - accuracy: 0.9812 - val_loss: 0.1164 - val_accuracy: 0.9625
# Epoch 80/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1236 - accuracy: 0.9563 - val_loss: 0.1033 - val_accuracy: 0.9750
# Epoch 81/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0923 - accuracy: 0.9750 - val_loss: 0.0847 - val_accuracy: 0.9750
# Epoch 82/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0647 - accuracy: 0.9937 - val_loss: 0.1383 - val_accuracy: 1.0000
# Epoch 83/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0890 - accuracy: 0.9625 - val_loss: 0.1112 - val_accuracy: 0.9750
# Epoch 84/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0909 - accuracy: 0.9688 - val_loss: 0.1370 - val_accuracy: 0.9500
# Epoch 85/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1042 - accuracy: 0.9625 - val_loss: 0.1524 - val_accuracy: 0.9500
# Epoch 86/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0941 - accuracy: 0.9688 - val_loss: 0.1139 - val_accuracy: 0.9750
# Epoch 87/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0929 - accuracy: 0.9625 - val_loss: 0.1238 - val_accuracy: 0.9750
# Epoch 88/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0749 - accuracy: 0.9812 - val_loss: 0.1148 - val_accuracy: 0.9625
# Epoch 89/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0874 - accuracy: 0.9750 - val_loss: 0.1340 - val_accuracy: 0.9250
# Epoch 90/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0795 - accuracy: 0.9812 - val_loss: 0.0974 - val_accuracy: 0.9750
# Epoch 91/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0694 - accuracy: 0.9812 - val_loss: 0.1486 - val_accuracy: 0.9750
# Epoch 92/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0862 - accuracy: 0.9750 - val_loss: 0.1092 - val_accuracy: 0.9875
# Epoch 93/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0695 - accuracy: 0.9750 - val_loss: 0.0818 - val_accuracy: 0.9750
# Epoch 94/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0681 - accuracy: 0.9812 - val_loss: 0.0709 - val_accuracy: 0.9750
# Epoch 95/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1003 - accuracy: 0.9688 - val_loss: 0.1027 - val_accuracy: 0.9375
# Epoch 96/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0770 - accuracy: 0.9812 - val_loss: 0.0879 - val_accuracy: 0.9625
# Epoch 97/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0630 - accuracy: 0.9875 - val_loss: 0.1140 - val_accuracy: 0.9500
# Epoch 98/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0599 - accuracy: 0.9875 - val_loss: 0.0835 - val_accuracy: 0.9875
# Epoch 99/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0637 - accuracy: 0.9812 - val_loss: 0.0933 - val_accuracy: 0.9750
# Epoch 100/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0610 - accuracy: 0.9812 - val_loss: 0.0686 - val_accuracy: 0.9750

# %%
model4, history4 = create_model(8, 4, 100)
# Out:
# Epoch 1/100
# 160/160 [==============================] - 1s 5ms/step - loss: 2.0985 - accuracy: 0.1250 - val_loss: 2.0747 - val_accuracy: 0.0875
# Epoch 2/100
# 160/160 [==============================] - 1s 3ms/step - loss: 2.0406 - accuracy: 0.2000 - val_loss: 2.0452 - val_accuracy: 0.1875
# Epoch 3/100
# 160/160 [==============================] - 1s 4ms/step - loss: 2.0099 - accuracy: 0.2375 - val_loss: 2.0269 - val_accuracy: 0.1875
# Epoch 4/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.9521 - accuracy: 0.2562 - val_loss: 2.0159 - val_accuracy: 0.2250
# Epoch 5/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.8375 - accuracy: 0.3688 - val_loss: 1.9002 - val_accuracy: 0.3000
# Epoch 6/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.6898 - accuracy: 0.4313 - val_loss: 1.7766 - val_accuracy: 0.3000
# Epoch 7/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.5755 - accuracy: 0.4313 - val_loss: 1.6797 - val_accuracy: 0.3000
# Epoch 8/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.4690 - accuracy: 0.4375 - val_loss: 1.6083 - val_accuracy: 0.3000
# Epoch 9/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.3726 - accuracy: 0.4375 - val_loss: 1.5264 - val_accuracy: 0.3125
# Epoch 10/100
# 160/160 [==============================] - 1s 4ms/step - loss: 1.3090 - accuracy: 0.4750 - val_loss: 1.4691 - val_accuracy: 0.4125
# Epoch 11/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.2445 - accuracy: 0.5063 - val_loss: 1.3990 - val_accuracy: 0.4500
# Epoch 12/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.1730 - accuracy: 0.5562 - val_loss: 1.3667 - val_accuracy: 0.4625
# Epoch 13/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.1073 - accuracy: 0.6125 - val_loss: 1.3077 - val_accuracy: 0.4250
# Epoch 14/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0439 - accuracy: 0.5938 - val_loss: 1.2125 - val_accuracy: 0.5000
# Epoch 15/100
# 160/160 [==============================] - 1s 3ms/step - loss: 1.0075 - accuracy: 0.6313 - val_loss: 1.1798 - val_accuracy: 0.5375
# Epoch 16/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.9471 - accuracy: 0.6313 - val_loss: 1.1173 - val_accuracy: 0.5375
# Epoch 17/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.8959 - accuracy: 0.7125 - val_loss: 1.1025 - val_accuracy: 0.5500
# Epoch 18/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.8629 - accuracy: 0.7063 - val_loss: 1.0102 - val_accuracy: 0.6375
# Epoch 19/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.8232 - accuracy: 0.7063 - val_loss: 1.0232 - val_accuracy: 0.5500
# Epoch 20/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.8082 - accuracy: 0.7188 - val_loss: 0.9443 - val_accuracy: 0.6125
# Epoch 21/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.7643 - accuracy: 0.7250 - val_loss: 0.9108 - val_accuracy: 0.6375
# Epoch 22/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.7363 - accuracy: 0.7375 - val_loss: 0.9174 - val_accuracy: 0.6625
# Epoch 23/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.7107 - accuracy: 0.7250 - val_loss: 0.8474 - val_accuracy: 0.6375
# Epoch 24/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.6821 - accuracy: 0.7125 - val_loss: 0.8426 - val_accuracy: 0.6375
# Epoch 25/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.6669 - accuracy: 0.7188 - val_loss: 0.7799 - val_accuracy: 0.6375
# Epoch 26/100
# 160/160 [==============================] - 1s 5ms/step - loss: 0.6408 - accuracy: 0.7375 - val_loss: 0.7604 - val_accuracy: 0.6500
# Epoch 27/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.6226 - accuracy: 0.7625 - val_loss: 0.8162 - val_accuracy: 0.6875
# Epoch 28/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.5959 - accuracy: 0.7688 - val_loss: 0.7713 - val_accuracy: 0.7250
# Epoch 29/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.5915 - accuracy: 0.7688 - val_loss: 0.6791 - val_accuracy: 0.6750
# Epoch 30/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.5587 - accuracy: 0.7875 - val_loss: 0.7223 - val_accuracy: 0.7750
# Epoch 31/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.5284 - accuracy: 0.7812 - val_loss: 0.6283 - val_accuracy: 0.7000
# Epoch 32/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.5379 - accuracy: 0.7812 - val_loss: 0.6318 - val_accuracy: 0.6750
# Epoch 33/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.5065 - accuracy: 0.8000 - val_loss: 0.6087 - val_accuracy: 0.7500
# Epoch 34/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.4826 - accuracy: 0.8188 - val_loss: 0.5759 - val_accuracy: 0.8125
# Epoch 35/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.4874 - accuracy: 0.8375 - val_loss: 0.6044 - val_accuracy: 0.8250
# Epoch 36/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.4665 - accuracy: 0.8313 - val_loss: 0.5644 - val_accuracy: 0.7375
# Epoch 37/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4540 - accuracy: 0.8500 - val_loss: 0.5396 - val_accuracy: 0.8375
# Epoch 38/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4422 - accuracy: 0.8438 - val_loss: 0.5422 - val_accuracy: 0.7625
# Epoch 39/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.4217 - accuracy: 0.8375 - val_loss: 0.5978 - val_accuracy: 0.8500
# Epoch 40/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.4334 - accuracy: 0.8562 - val_loss: 0.5242 - val_accuracy: 0.7875
# Epoch 41/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.4238 - accuracy: 0.8687 - val_loss: 0.4959 - val_accuracy: 0.8000
# Epoch 42/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3965 - accuracy: 0.8500 - val_loss: 0.4689 - val_accuracy: 0.9000
# Epoch 43/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3939 - accuracy: 0.8875 - val_loss: 0.4735 - val_accuracy: 0.7625
# Epoch 44/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3876 - accuracy: 0.8625 - val_loss: 0.4578 - val_accuracy: 0.8500
# Epoch 45/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3617 - accuracy: 0.8813 - val_loss: 0.4346 - val_accuracy: 0.8625
# Epoch 46/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.3619 - accuracy: 0.9000 - val_loss: 0.4259 - val_accuracy: 0.9000
# Epoch 47/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3450 - accuracy: 0.8875 - val_loss: 0.4127 - val_accuracy: 0.8875
# Epoch 48/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3393 - accuracy: 0.8938 - val_loss: 0.4078 - val_accuracy: 0.8750
# Epoch 49/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3225 - accuracy: 0.9000 - val_loss: 0.3887 - val_accuracy: 0.9125
# Epoch 50/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3089 - accuracy: 0.9062 - val_loss: 0.3931 - val_accuracy: 0.9000
# Epoch 51/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.3034 - accuracy: 0.9250 - val_loss: 0.3972 - val_accuracy: 0.9000
# Epoch 52/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2996 - accuracy: 0.9000 - val_loss: 0.3763 - val_accuracy: 0.8750
# Epoch 53/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2868 - accuracy: 0.9125 - val_loss: 0.3528 - val_accuracy: 0.9125
# Epoch 54/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2758 - accuracy: 0.9375 - val_loss: 0.3614 - val_accuracy: 0.9000
# Epoch 55/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2658 - accuracy: 0.9375 - val_loss: 0.3465 - val_accuracy: 0.9000
# Epoch 56/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2666 - accuracy: 0.9438 - val_loss: 0.3690 - val_accuracy: 0.9000
# Epoch 57/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2481 - accuracy: 0.9312 - val_loss: 0.3237 - val_accuracy: 0.9000
# Epoch 58/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2475 - accuracy: 0.9500 - val_loss: 0.2988 - val_accuracy: 0.9375
# Epoch 59/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2517 - accuracy: 0.9250 - val_loss: 0.2994 - val_accuracy: 0.9125
# Epoch 60/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2250 - accuracy: 0.9563 - val_loss: 0.3163 - val_accuracy: 0.9125
# Epoch 61/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2327 - accuracy: 0.9438 - val_loss: 0.2985 - val_accuracy: 0.9250
# Epoch 62/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2105 - accuracy: 0.9375 - val_loss: 0.2640 - val_accuracy: 0.9250
# Epoch 63/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2092 - accuracy: 0.9500 - val_loss: 0.2660 - val_accuracy: 0.9375
# Epoch 64/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.2266 - accuracy: 0.9250 - val_loss: 0.2657 - val_accuracy: 0.9125
# Epoch 65/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.2036 - accuracy: 0.9625 - val_loss: 0.3068 - val_accuracy: 0.9125
# Epoch 66/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1894 - accuracy: 0.9500 - val_loss: 0.2889 - val_accuracy: 0.9125
# Epoch 67/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1908 - accuracy: 0.9563 - val_loss: 0.2721 - val_accuracy: 0.9125
# Epoch 68/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1932 - accuracy: 0.9438 - val_loss: 0.3227 - val_accuracy: 0.9125
# Epoch 69/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1785 - accuracy: 0.9625 - val_loss: 0.2566 - val_accuracy: 0.9125
# Epoch 70/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1813 - accuracy: 0.9563 - val_loss: 0.2720 - val_accuracy: 0.9000
# Epoch 71/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1706 - accuracy: 0.9688 - val_loss: 0.2415 - val_accuracy: 0.9250
# Epoch 72/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1684 - accuracy: 0.9688 - val_loss: 0.2532 - val_accuracy: 0.9375
# Epoch 73/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1839 - accuracy: 0.9563 - val_loss: 0.3272 - val_accuracy: 0.8875
# Epoch 74/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1732 - accuracy: 0.9563 - val_loss: 0.2520 - val_accuracy: 0.9250
# Epoch 75/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1605 - accuracy: 0.9750 - val_loss: 0.2238 - val_accuracy: 0.9250
# Epoch 76/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1458 - accuracy: 0.9625 - val_loss: 0.2138 - val_accuracy: 0.9250
# Epoch 77/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1499 - accuracy: 0.9688 - val_loss: 0.2120 - val_accuracy: 0.9250
# Epoch 78/100
# 160/160 [==============================] - 0s 3ms/step - loss: 0.1516 - accuracy: 0.9563 - val_loss: 0.2252 - val_accuracy: 0.9000
# Epoch 79/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1518 - accuracy: 0.9563 - val_loss: 0.2007 - val_accuracy: 0.9250
# Epoch 80/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1497 - accuracy: 0.9688 - val_loss: 0.2679 - val_accuracy: 0.9250
# Epoch 81/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1801 - accuracy: 0.9563 - val_loss: 0.2014 - val_accuracy: 0.9250
# Epoch 82/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1307 - accuracy: 0.9688 - val_loss: 0.2128 - val_accuracy: 0.9500
# Epoch 83/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1543 - accuracy: 0.9688 - val_loss: 0.2228 - val_accuracy: 0.9250
# Epoch 84/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1428 - accuracy: 0.9625 - val_loss: 0.1887 - val_accuracy: 0.9250
# Epoch 85/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1419 - accuracy: 0.9563 - val_loss: 0.2332 - val_accuracy: 0.9500
# Epoch 86/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1269 - accuracy: 0.9563 - val_loss: 0.1883 - val_accuracy: 0.9375
# Epoch 87/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1279 - accuracy: 0.9688 - val_loss: 0.1819 - val_accuracy: 0.9375
# Epoch 88/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1351 - accuracy: 0.9688 - val_loss: 0.2382 - val_accuracy: 0.9000
# Epoch 89/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1252 - accuracy: 0.9812 - val_loss: 0.2191 - val_accuracy: 0.9250
# Epoch 90/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1235 - accuracy: 0.9688 - val_loss: 0.1939 - val_accuracy: 0.9250
# Epoch 91/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1130 - accuracy: 0.9750 - val_loss: 0.1869 - val_accuracy: 0.9500
# Epoch 92/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1415 - accuracy: 0.9688 - val_loss: 0.1756 - val_accuracy: 0.9375
# Epoch 93/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1221 - accuracy: 0.9625 - val_loss: 0.1842 - val_accuracy: 0.9375
# Epoch 94/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1264 - accuracy: 0.9625 - val_loss: 0.1884 - val_accuracy: 0.9375
# Epoch 95/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1247 - accuracy: 0.9688 - val_loss: 0.2110 - val_accuracy: 0.9375
# Epoch 96/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1217 - accuracy: 0.9688 - val_loss: 0.1600 - val_accuracy: 0.9375
# Epoch 97/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1204 - accuracy: 0.9625 - val_loss: 0.1696 - val_accuracy: 0.9250
# Epoch 98/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.1397 - accuracy: 0.9625 - val_loss: 0.1873 - val_accuracy: 0.9500
# Epoch 99/100
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1060 - accuracy: 0.9812 - val_loss: 0.1905 - val_accuracy: 0.9125
# Epoch 100/100
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0954 - accuracy: 0.9812 - val_loss: 0.1463 - val_accuracy: 0.9500

# %%
models = [model1, model2, model3, model4]
histories = [history1, history2, history3, history4]

# %% [markdown]
# ## Review models' performance

# %%
# increase the size of the graphs. The default size is (6,4).
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
def plot_model_loss(history, title, i):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(loss) + 1)
    
    ax = axs[int(i/2), i % 2]
    ax.plot(epochs, loss, 'g.', label='Training loss')
    ax.plot(epochs, val_loss, 'b.', label='Validation loss')
    ax.set_title(title)
#     ax.xlabel('Epochs')
#     ax.ylabel('Loss')
    ax.set(xlabel='Epochs', ylabel='Loss')
    ax.legend()
#     ax.show()

for i in range(4):
    plot_model_loss(histories[i], 'Model '+ str(i+1) + ' train/validate loss', i)

# %%
# increase the size of the graphs. The default size is (6,4).
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
def plot_model_accuracy(history, title, i):
    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    epochs = range(1, len(accuracy) + 1)
    
    ax = axs[int(i/2), i % 2]
    ax.plot(epochs, accuracy, 'g.', label='Training accuracy')
    ax.plot(epochs, val_accuracy, 'b.', label='Validation accuracy')
    ax.set_title(title)
    ax.set(xlabel='Epochs', ylabel='Loss')
    ax.legend()

for i in range(4):
    plot_model_accuracy(histories[i], 'Model '+ str(i+1) + ' accuracy', i)

# %%
models[0](i_test[:1])
# Out:
# <tf.Tensor: shape=(1, 8), dtype=float32, numpy=
# array([[9.0152898e-06, 1.3793069e-09, 5.0389503e-06, 5.5734140e-10,
#         2.8369317e-05, 1.1362351e-03, 9.9072683e-01, 8.0943583e-03]],
#       dtype=float32)>

# %% [markdown]
# ## Verify models with test data

# %%
fig, axs = plt.subplots(2, 2, figsize=(7, 7))
fig.tight_layout(pad=5.0)
def plot_cm(model, title, i):
    predict = model.predict(i_test)
    conf_mat = confusion_matrix(np.argmax(o_test, axis=1), np.argmax(predict, axis=1))
    ax = axs[int(i/2), i % 2]
    sb.heatmap(conf_mat, annot=True, cmap='Blues', fmt='g', cbar=False, ax=ax)
    ax.set_title(title)
    ax.set(xlabel='Actual labels', ylabel='Predicted labels')

for i in range(4):
    plot_cm(models[i], 'Model '+ str(i+1) + ' predict test data', i)
# Out:
# 3/3 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 3ms/step
# 3/3 [==============================] - 0s 2ms/step

# %% [markdown]
# ## Produce model file (.tflite)
#
# Output both non-quantized and quantized model files

# %%
def representative_dataset_generator():
 # each scalar value inside a 2D array that is wrapped in a list
 for value in inputs:
     yield [np.array(value, dtype=np.float32, ndmin=2)]



for i, model in enumerate(models):
    TFLITE_FILE = 'tflite/test_complexity/gesture_model_' + str(i+1) + '.tflite'
    TFLITE_FILE_Q = 'tflite/test_complexity/gesture_model_' + str(i+1) + 'q.tflite'
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    tflite_model = converter.convert()
    open(TFLITE_FILE, "wb").write(tflite_model)
    
    converter_q = tf.lite.TFLiteConverter.from_keras_model(model)
    converter_q.optimizations = [tf.lite.Optimize.DEFAULT]
    converter_q.representative_dataset = representative_dataset_generator
    tflite_model_q = converter_q.convert()
    open(TFLITE_FILE_Q, "wb").write(tflite_model_q)
    
    # Review size difference
    basic_model_size = os.path.getsize(TFLITE_FILE)
    print("Basic model{} is {} bytes".format(i, basic_model_size))

    basic_model_size_q = os.path.getsize(TFLITE_FILE_Q)
    print("Quantized model{} is {} bytes".format(i, basic_model_size_q))
# Out:
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpwa62vqjx\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmp5jxh_eo0\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmp5jxh_eo0\assets
# C:\Users\cheew\anaconda3\envs\tf\lib\site-packages\tensorflow\lite\python\convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# Basic model0 is 57804 bytes
# Quantized model0 is 17072 bytes
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpar3mfm2u\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpar3mfm2u\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpc1e4h2er\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpc1e4h2er\assets
# C:\Users\cheew\anaconda3\envs\tf\lib\site-packages\tensorflow\lite\python\convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# Basic model1 is 27948 bytes
# Quantized model1 is 9480 bytes
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpl10b6tc8\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpl10b6tc8\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpzs8nj0iv\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpzs8nj0iv\assets
# C:\Users\cheew\anaconda3\envs\tf\lib\site-packages\tensorflow\lite\python\convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# Basic model2 is 14540 bytes
# Quantized model2 is 6056 bytes
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmp3h21f8bo\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmp3h21f8bo\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpkfau87nz\assets
# INFO:tensorflow:Assets written to: C:\Users\cheew\AppData\Local\Temp\tmpkfau87nz\assets
# Basic model3 is 8244 bytes
# Quantized model3 is 4464 bytes
# C:\Users\cheew\anaconda3\envs\tf\lib\site-packages\tensorflow\lite\python\convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "

# %% [markdown]
# ## Verify the interpreter (.tflite)

# %%
fig, axs = plt.subplots(2, 2, figsize=(7, 7))
fig.tight_layout(pad=5.0)

for i in range(4):
    TFLITE_FILE = 'tflite/test_complexity/gesture_model_' + str(i+1) + '.tflite'
    model = tf.lite.Interpreter(TFLITE_FILE)
    model.allocate_tensors()
    model_input_index = model.get_input_details()[0]['index']
    model_output_index = model.get_output_details()[0]['index']
    predict = []
    for j in i_test:
    # write the value to the input tensor
        i_tensor = tf.convert_to_tensor([j], dtype=tf.float32)
        model.set_tensor(model_input_index, i_tensor)
        # run inference
        model.invoke()
        # read the prediction from the output tensor
        predict.append(model.get_tensor(model_output_index)[0])
        
    ax = axs[int(i/2), i % 2]
    conf_mat = confusion_matrix(np.argmax(o_test, axis=1), np.argmax(predict, axis=1))
    ax = axs[int(i/2), i % 2]
    sb.heatmap(conf_mat, annot=True, cmap='Blues', fmt='g', cbar=False, ax=ax)
    ax.set_title("Model " + str(i+1))
    ax.set(xlabel='Actual labels', ylabel='Predicted labels')

# %% [markdown]
# ## Verify the quantized interpreter (.tflite)

# %%
fig, axs = plt.subplots(2, 2, figsize=(7, 7))
fig.tight_layout(pad=5.0)

for i in range(4):
    TFLITE_FILE_Q = 'tflite/test_complexity/gesture_model_' + str(i+1) + 'q.tflite'
    model = tf.lite.Interpreter(TFLITE_FILE_Q)
    model.allocate_tensors()
    model_input_index = model.get_input_details()[0]['index']
    model_output_index = model.get_output_details()[0]['index']
    predict = []
    for j in i_test:
    # write the value to the input tensor
        i_tensor = tf.convert_to_tensor([j], dtype=tf.float32)
        model.set_tensor(model_input_index, i_tensor)
        # run inference
        model.invoke()
        # read the prediction from the output tensor
        predict.append(model.get_tensor(model_output_index)[0])
        
    ax = axs[int(i/2), i % 2]
    conf_mat = confusion_matrix(np.argmax(o_test, axis=1), np.argmax(predict, axis=1))
    ax = axs[int(i/2), i % 2]
    sb.heatmap(conf_mat, annot=True, cmap='Blues', fmt='g', cbar=False, ax=ax)
    ax.set_title("Model " + str(i+1))
    ax.set(xlabel='Actual labels', ylabel='Predicted labels')

# %% [markdown]
# ## Produce the model header file

# %%
# to run below command, ensure jupyter notebook is launched under bash terminal (eg. git bash, linux terminal)

for i in range(4):
    TFLITE_FILE = 'tflite/test_complexity/gesture_model_' + str(i+1) + '.tflite'
    TFLITE_FILE_Q = 'tflite/test_complexity/gesture_model_' + str(i+1) + 'q.tflite'
    
    HEADER_FILE = '../ble_client/test_complexity/gesture_model_'+str(i+1)+'.h'
    HEADER_FILE_Q = '../ble_client/test_complexity/gesture_model_'+str(i+1)+'q.h'
    # based model header file
    str1 = "const unsigned char {} [] = {{".format('gesture_model')
    str2 = "};"

    # !echo {str1}  > {HEADER_FILE}
    # !cat {TFLITE_FILE} | xxd -i >> {HEADER_FILE}
    # !echo {str2} >> {HEADER_FILE}

    # quantized model header file
    str3 = "const unsigned char {} [] = {{".format('gesture_model_q')

    # !echo {str3}  > {HEADER_FILE_Q}
    # !cat {TFLITE_FILE_Q} | xxd -i >> {HEADER_FILE_Q}
    # !echo {str2} >> {HEADER_FILE_Q}
